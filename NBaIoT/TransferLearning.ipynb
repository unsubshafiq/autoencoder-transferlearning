# %%
# Importing general libraries
from glob import iglob
import math
import time
import  sys
import difflib

# Import ML related libraries
import tensorflow as tf
import keras
from tensorflow.keras.utils import plot_model
from keras.models import load_model
from keras.models import Model, Sequential
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from keras import backend as K
from keras.initializers import glorot_uniform
#from keras.optimizers import SGD
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import recall_score, accuracy_score, precision_score, confusion_matrix, plot_confusion_matrix
#import lime
#import lime.lime_tabular
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# Checking the version of the of installed / available libraries
print("Python: " + str(sys.version_info.major) + "." + str(sys.version_info.minor))
print("Tensorflow: " + str(tf.__version__))
print("Keras: " + str(keras.__version__))
print("ScikitLearn: " + str(sklearn.__version__))
print("Pandas: " + str(pd.__version__))
print("NumPy: " + str(np.__version__))

# Fetching the data from Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Python: 3.7
# Tensorflow: 2.7.0
# Keras: 2.7.0
# ScikitLearn: 1.0.2
# Pandas: 1.1.5
# NumPy: 1.19.5
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# MetaData
Device_Listing = ['SimpleHome_XCS7_1003_WHT_Security_Camera',  
                 'SimpleHome_XCS7_1002_WHT_Security_Camera',
                 'Provision_PT_838_Security_Camera',
                 'Provision_PT_737E_Security_Camera',
                 'Danmini_Doorbell',
                 'Ennio_Doorbell',
                 'Ecobee_Thermostat',
                 'Samsung_SNH_1011_N_Webcam',
                 'Philips_B120N10_Baby_Monitor']

Malware_Listing = ['Mirai',
                  'Bashlite']

# %% [markdown]
# # Setting Variables

# %%
# Environment Variables

Known_Devices = ['Provision_PT_838_Security_Camera']
Unknown_Devices = ['Ecobee_Thermostat']

# At the moment, it is not expected that both of the following booleans shall be true at the same time. Our analysis is for a single malware at a time.
Run_For_Malware_Mirai = 0
Run_For_Malware_Bashlite = 1

# Fisher Score Variables
fisher_score_use_top_n_features = 115 #(max value is 115, reducing this value will reduce the total pool of features to use in training)
use_features_with_fisher_score_greater_than = 0.1 #(when set to 0, will use all top_n features allowed in above variable. For none zero values, will only use features from the top_n variable above
                                                # whose fisher score is greater than the value set in this variable.)

# This name shall be used to generate relevant save file names at relevant paths
savefilename='Known-SimpleHomeCamera_Unknown-Provision'
transfer_savefilename='Transfer-Known-SimpleHomeCamera_Unknown-Provision'

checkpoint_filepath=f"/content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/{savefilename}-{use_features_with_fisher_score_greater_than}.h5"
transfer_learning_checkpoint_filepath=f"/content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/{transfer_savefilename}-{use_features_with_fisher_score_greater_than}.h5"
Known_F_Score_File=f"/content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Fisher-Scores/{savefilename}-A-{use_features_with_fisher_score_greater_than}.csv"
Unknown_F_Score_File=f"/content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Fisher-Scores/{savefilename}-B-{use_features_with_fisher_score_greater_than}.csv"

# %% [markdown]
# **First, we shall do all of our work related to the Known device and then proceed towards the unknown devices**
#
# **Collecting Data for the Known Devices. Both Benign and Attack data shall be included.**

# %%
print("====-- Loading Benign Data --====\n")

filepaths = []
for device in Known_Devices:
  print(device)
  path = f"/content/drive/My Drive/thesis-unsub/data/{device}/benign_traffic.csv"
  filepaths.append(path)

df_known_device_benign = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)
print("\n Benign DataFrame Information\n------")
df_known_device_benign.info()


print("\n\n=========\n\n")


if Run_For_Malware_Mirai:
  print("====-- Loading Attack Data - Mirai --====\n")
  Mirai_Filepaths = []
  for device in Known_Devices:
    print(device)
    path = f"/content/drive/My Drive/thesis-unsub/data/{device}/mirai_attacks/"
    for files in ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']:
      filepath = path + str(files)
      Mirai_Filepaths.append(filepath)

  print(Mirai_Filepaths)

  df_known_device_attack= pd.concat((pd.read_csv(f) for f in Mirai_Filepaths), ignore_index=True)
  print("\n Malware DataFrame Information - Mirai\n------")
  df_known_device_attack.info()



if Run_For_Malware_Bashlite:
  Bashlite_Filepaths = []
  for device in Known_Devices:
    print(device)
    path = f"/content/drive/My Drive/thesis-unsub/data/{device}/gafgyt_attacks/"
    for files in ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']:
      filepath = path + str(files)
      Bashlite_Filepaths.append(filepath)

  print(Bashlite_Filepaths)

  df_known_device_attack = pd.concat((pd.read_csv(f) for f in Bashlite_Filepaths), ignore_index=True)
  print("\nDataFrame Information\n------")
  df_known_device_attack.info()
# Out:
# ====-- Loading Benign Data --====
#
# Provision_PT_838_Security_Camera
#
#  Benign DataFrame Information
# ------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98514 entries, 0 to 98513
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 86.4 MB
#
#
# =========
#
#
# Provision_PT_838_Security_Camera
# ['/content/drive/My Drive/thesis-unsub/data/Provision_PT_838_Security_Camera/gafgyt_attacks/combo.csv', '/content/drive/My Drive/thesis-unsub/data/Provision_PT_838_Security_Camera/gafgyt_attacks/junk.csv', '/content/drive/My Drive/thesis-unsub/data/Provision_PT_838_Security_Camera/gafgyt_attacks/scan.csv', '/content/drive/My Drive/thesis-unsub/data/Provision_PT_838_Security_Camera/gafgyt_attacks/tcp.csv', '/content/drive/My Drive/thesis-unsub/data/Provision_PT_838_Security_Camera/gafgyt_attacks/udp.csv']
#
# DataFrame Information
# ------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309040 entries, 0 to 309039
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 271.1 MB

# %%
#print("Randomly selecting 10% of the benign data")
#df_known_device_benign_frac = df_known_device_benign.sample(frac=0.1)

print("Splitting Benign Data into 3 parts for training, optimization and test in a 60/20/20 split")
#df_benign_train, df_benign_opt, df_benign_test = np.split(df_benign.sample(frac=1, random_state=406), [int(1/3*len(df_benign)), int(2/3*len(df_benign))])
#df_known_device_benign_train, df_known_device_benign_opt, df_known_device_benign_test = np.split(df_known_device_benign.sample(frac=1, random_state=406), [int(3/5*len(df_known_device_benign)), int(4/5*len(df_known_device_benign))])

#df_known_device_benign_train, df_known_device_benign_opt, df_known_device_benign_test = np.split(df_known_device_benign_frac.sample(frac=1), [int(3/5*len(df_known_device_benign_frac)), int(4/5*len(df_known_device_benign_frac))])
df_known_device_benign_train, df_known_device_benign_opt, df_known_device_benign_test = np.split(df_known_device_benign.sample(frac=1), [int(3/5*len(df_known_device_benign)), int(4/5*len(df_known_device_benign))])

print("Split Information")
print("df_known_device_benign_train: " + str(df_known_device_benign_train.shape))
print("df_known_device_benign_opt:   " + str(df_known_device_benign_opt.shape))
print("df_known_device_benign_test:  " + str(df_known_device_benign_test.shape))
print("\n")

print("Information about the Split\nTraining Data\n---")
df_known_device_benign_train.info()

print("\nOptimization Data\n---")
df_known_device_benign_opt.info()

print("\nTest Data\n---")
df_known_device_benign_test.info()
# Out:
# Splitting Benign Data into 3 parts for training, optimization and test in a 60/20/20 split
# Split Information
# df_known_device_benign_train: (59108, 115)
# df_known_device_benign_opt:   (19703, 115)
# df_known_device_benign_test:  (19703, 115)
#
#
# Information about the Split
# Training Data
# ---
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59108 entries, 34670 to 15417
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 52.3 MB
#
# Optimization Data
# ---
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19703 entries, 40569 to 33442
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 17.4 MB
#
# Test Data
# ---
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19703 entries, 45384 to 91869
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 17.4 MB

# %% [markdown]
# **Scaling the Bengin (train, opt, test) and the attack datasets**

# %%
# Extracting the column names from our dataset for use later,
col_list = []
for col in df_known_device_benign_train.columns:
  col_list.append(col)

print(col_list)

# Implementing the Normalization, We fit normalization parameters on the train dataset and use them to scale the opt, test and attack datasets.
scaler = MinMaxScaler()

scaled_df_known_device_benign_train = scaler.fit_transform(df_known_device_benign_train)
scaled_df_known_device_benign_opt = scaler.transform(df_known_device_benign_opt)
scaled_df_known_device_benign_test = scaler.transform(df_known_device_benign_test)

scaled_df_known_device_attack = scaler.transform(df_known_device_attack)


#Converting NumPy arrays back to Pandas DataFrames
scaled_df_known_device_benign_train = pd.DataFrame(scaled_df_known_device_benign_train, columns=col_list)
scaled_df_known_device_benign_opt = pd.DataFrame(scaled_df_known_device_benign_opt, columns=col_list)
scaled_df_known_device_benign_test = pd.DataFrame(scaled_df_known_device_benign_test, columns=col_list)

scaled_df_known_device_attack = pd.DataFrame(scaled_df_known_device_attack, columns=col_list)
# Out:
# ['MI_dir_L5_weight', 'MI_dir_L5_mean', 'MI_dir_L5_variance', 'MI_dir_L3_weight', 'MI_dir_L3_mean', 'MI_dir_L3_variance', 'MI_dir_L1_weight', 'MI_dir_L1_mean', 'MI_dir_L1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean', 'MI_dir_L0.1_variance', 'MI_dir_L0.01_weight', 'MI_dir_L0.01_mean', 'MI_dir_L0.01_variance', 'H_L5_weight', 'H_L5_mean', 'H_L5_variance', 'H_L3_weight', 'H_L3_mean', 'H_L3_variance', 'H_L1_weight', 'H_L1_mean', 'H_L1_variance', 'H_L0.1_weight', 'H_L0.1_mean', 'H_L0.1_variance', 'H_L0.01_weight', 'H_L0.01_mean', 'H_L0.01_variance', 'HH_L5_weight', 'HH_L5_mean', 'HH_L5_std', 'HH_L5_magnitude', 'HH_L5_radius', 'HH_L5_covariance', 'HH_L5_pcc', 'HH_L3_weight', 'HH_L3_mean', 'HH_L3_std', 'HH_L3_magnitude', 'HH_L3_radius', 'HH_L3_covariance', 'HH_L3_pcc', 'HH_L1_weight', 'HH_L1_mean', 'HH_L1_std', 'HH_L1_magnitude', 'HH_L1_radius', 'HH_L1_covariance', 'HH_L1_pcc', 'HH_L0.1_weight', 'HH_L0.1_mean', 'HH_L0.1_std', 'HH_L0.1_magnitude', 'HH_L0.1_radius', 'HH_L0.1_covariance', 'HH_L0.1_pcc', 'HH_L0.01_weight', 'HH_L0.01_mean', 'HH_L0.01_std', 'HH_L0.01_magnitude', 'HH_L0.01_radius', 'HH_L0.01_covariance', 'HH_L0.01_pcc', 'HH_jit_L5_weight', 'HH_jit_L5_mean', 'HH_jit_L5_variance', 'HH_jit_L3_weight', 'HH_jit_L3_mean', 'HH_jit_L3_variance', 'HH_jit_L1_weight', 'HH_jit_L1_mean', 'HH_jit_L1_variance', 'HH_jit_L0.1_weight', 'HH_jit_L0.1_mean', 'HH_jit_L0.1_variance', 'HH_jit_L0.01_weight', 'HH_jit_L0.01_mean', 'HH_jit_L0.01_variance', 'HpHp_L5_weight', 'HpHp_L5_mean', 'HpHp_L5_std', 'HpHp_L5_magnitude', 'HpHp_L5_radius', 'HpHp_L5_covariance', 'HpHp_L5_pcc', 'HpHp_L3_weight', 'HpHp_L3_mean', 'HpHp_L3_std', 'HpHp_L3_magnitude', 'HpHp_L3_radius', 'HpHp_L3_covariance', 'HpHp_L3_pcc', 'HpHp_L1_weight', 'HpHp_L1_mean', 'HpHp_L1_std', 'HpHp_L1_magnitude', 'HpHp_L1_radius', 'HpHp_L1_covariance', 'HpHp_L1_pcc', 'HpHp_L0.1_weight', 'HpHp_L0.1_mean', 'HpHp_L0.1_std', 'HpHp_L0.1_magnitude', 'HpHp_L0.1_radius', 'HpHp_L0.1_covariance', 'HpHp_L0.1_pcc', 'HpHp_L0.01_weight', 'HpHp_L0.01_mean', 'HpHp_L0.01_std', 'HpHp_L0.01_magnitude', 'HpHp_L0.01_radius', 'HpHp_L0.01_covariance', 'HpHp_L0.01_pcc']

# %% [markdown]
# Adding labels to the dataframes

# %%
scaled_df_known_device_attack['class'] = 'attack'
scaled_df_known_device_benign_train['class'] = 'benign'
scaled_df_known_device_benign_opt['class'] = 'benign'
scaled_df_known_device_benign_test['class'] = 'benign'

# %% [markdown]
# **Time to calculate the Fisher Score and identify the most valuable features from the known devices benign and attack datasets**

# %%
## Fisher Scoring, for Fisher scoring we shall use the attack data of the same devices
## for which we trained our benign model.

# Creating a Fisher dataframe that shall contain an equal mix of benign_train and attack data.
# Removing randomizing states. We shall have multiple runs and tabulation of results.
# scaled_df_fisher = scaled_df_known_device_benign_train.append(scaled_df_known_device_attack.sample(n=scaled_df_known_device_benign_train.shape[0], random_state=406))
scaled_df_fisher = scaled_df_known_device_benign_train.append(scaled_df_known_device_attack.sample(n=scaled_df_known_device_benign_train.shape[0]))

print(scaled_df_fisher.shape)
scored = [] # declare a list
indices = {} # declare two dictionaries, purpose unknown
shps = {}
classes = ['benign','attack']

for cl in classes:
    indices[cl] = scaled_df_fisher['class'] == cl # Now here, above created Fisher dataframe shall have two classes only.
                                           # so half of the time the comparison output shall be true and false
                                           # for the rest.
                                           # It creates a Pandas series
    shps[cl] = scaled_df_fisher[indices[cl]].shape[0] # dictionary contains the number of rows of benign traffic and the
                                               # number of rows for the attack traffic

for col in scaled_df_fisher.columns: # Loop through all the columns of the Fisher DataFrame
    if col == 'class':  # if the column is that of "Class", then skip it.
        continue
    num = 0
    den = 0
    m = scaled_df_fisher[col].mean() # For the column under the current iteration, find the mean value.
                            # no, nothing strange about this. We are finding out the mean of each field/column
                            # in the dataset.
    
    for cl in classes: # For each column (this essentially means that we are considering that column at the moment)
                       # calculate the numerator and the denominator values for the Fisher score per class.
        num += (shps[cl] / scaled_df_fisher.shape[0]) * (m - scaled_df_fisher[indices[cl]][col].mean())**2
                # shps[cl] --> e.g if shps['benign'] then number of rows in it shall be 33032
                # (33032/66064) * ([mean-of-that-whole-column] - mean-of-rows-whose class was cl)**2
        den += (shps[cl] / scaled_df_fisher.shape[0]) * scaled_df_fisher[indices[cl]][col].var()
                # shps[cl] --> e.g if shps['benign'] then number of rows in it shall be 33032
                # (33032/66064) * (variance-of-rows-whose class was cl)
        
    score = {'feature': col, 'score': num / den}
    scored.append(score)
    #print(score)
scored.sort(key=lambda x: x['score'], reverse=True)
scored[:115] #scored is a list of dictionaries    


# Write down the calculated F-scores in a file.
with open(Known_F_Score_File, 'w+') as file:
    lines = ['Feature,Score\n']
    for s in scored:
        lines.append(s['feature'] + ',' + "{0:.2f}".format(s['score']) + '\n')
    file.writelines(lines)

lines
# Out:
# (118216, 116)
# ['Feature,Score\n',
#  'H_L0.01_mean,1.15\n',
#  'MI_dir_L0.01_mean,1.15\n',
#  'HH_jit_L0.01_mean,1.13\n',
#  'HH_jit_L0.1_mean,1.11\n',
#  'HH_jit_L1_mean,0.98\n',
#  'HH_jit_L3_mean,0.96\n',
#  'HH_jit_L5_mean,0.96\n',
#  'H_L0.1_mean,0.65\n',
#  'MI_dir_L0.1_mean,0.65\n',
#  'H_L0.01_variance,0.59\n',
#  'MI_dir_L0.01_variance,0.59\n',
#  'HH_L0.01_magnitude,0.48\n',
#  'HH_L0.01_mean,0.41\n',
#  'HH_L0.01_std,0.38\n',
#  'MI_dir_L1_mean,0.37\n',
#  'H_L1_mean,0.37\n',
#  'HH_L0.1_magnitude,0.36\n',
#  'HH_L0.1_mean,0.33\n',
#  'H_L0.1_variance,0.32\n',
#  'MI_dir_L0.1_variance,0.32\n',
#  'MI_dir_L3_mean,0.31\n',
#  'H_L3_mean,0.31\n',
#  'HH_L1_magnitude,0.29\n',
#  'MI_dir_L5_mean,0.29\n',
#  'H_L5_mean,0.29\n',
#  'HH_L1_mean,0.28\n',
#  'HH_L3_magnitude,0.26\n',
#  'HH_L0.01_radius,0.26\n',
#  'HH_L3_mean,0.26\n',
#  'HH_L0.1_std,0.26\n',
#  'HH_L5_mean,0.26\n',
#  'HH_L5_magnitude,0.25\n',
#  'HH_L1_std,0.20\n',
#  'MI_dir_L0.1_weight,0.20\n',
#  'H_L0.1_weight,0.20\n',
#  'MI_dir_L1_weight,0.20\n',
#  'H_L1_weight,0.20\n',
#  'HpHp_L1_weight,0.20\n',
#  'HH_L0.1_radius,0.20\n',
#  'HH_L3_std,0.19\n',
#  'MI_dir_L1_variance,0.18\n',
#  'H_L1_variance,0.18\n',
#  'MI_dir_L3_weight,0.18\n',
#  'H_L3_weight,0.18\n',
#  'HH_L5_std,0.18\n',
#  'HH_jit_L0.1_weight,0.18\n',
#  'HH_L0.1_weight,0.18\n',
#  'MI_dir_L0.01_weight,0.17\n',
#  'H_L0.01_weight,0.17\n',
#  'HH_jit_L1_weight,0.17\n',
#  'HH_L1_weight,0.17\n',
#  'HH_L1_radius,0.17\n',
#  'MI_dir_L5_weight,0.17\n',
#  'H_L5_weight,0.17\n',
#  'HpHp_L0.01_mean,0.16\n',
#  'HpHp_L1_mean,0.16\n',
#  'HpHp_L3_mean,0.16\n',
#  'HpHp_L5_mean,0.16\n',
#  'HpHp_L0.1_weight,0.16\n',
#  'HpHp_L0.1_mean,0.16\n',
#  'HH_L3_radius,0.16\n',
#  'HpHp_L3_weight,0.16\n',
#  'HpHp_L0.01_magnitude,0.15\n',
#  'HpHp_L0.1_magnitude,0.15\n',
#  'HH_L5_radius,0.15\n',
#  'HpHp_L1_magnitude,0.15\n',
#  'HpHp_L3_magnitude,0.15\n',
#  'HpHp_L5_magnitude,0.15\n',
#  'HH_jit_L3_weight,0.15\n',
#  'HH_L3_weight,0.15\n',
#  'HpHp_L5_weight,0.15\n',
#  'MI_dir_L3_variance,0.14\n',
#  'H_L3_variance,0.14\n',
#  'HH_L0.01_weight,0.14\n',
#  'HH_jit_L0.01_weight,0.14\n',
#  'MI_dir_L5_variance,0.14\n',
#  'H_L5_variance,0.14\n',
#  'HH_jit_L5_weight,0.14\n',
#  'HH_L5_weight,0.14\n',
#  'HpHp_L0.01_std,0.12\n',
#  'HpHp_L0.1_std,0.12\n',
#  'HpHp_L1_std,0.11\n',
#  'HpHp_L3_std,0.11\n',
#  'HH_L0.1_covariance,0.11\n',
#  'HpHp_L5_std,0.11\n',
#  'HpHp_L3_pcc,0.07\n',
#  'HpHp_L1_pcc,0.07\n',
#  'HpHp_L5_pcc,0.07\n',
#  'HpHp_L0.01_pcc,0.07\n',
#  'HpHp_L0.01_weight,0.07\n',
#  'HpHp_L0.1_covariance,0.07\n',
#  'HpHp_L1_covariance,0.07\n',
#  'HpHp_L3_covariance,0.07\n',
#  'HpHp_L5_covariance,0.07\n',
#  'HpHp_L0.01_covariance,0.07\n',
#  'HpHp_L1_radius,0.07\n',
#  'HpHp_L3_radius,0.07\n',
#  'HH_L1_covariance,0.07\n',
#  'HpHp_L5_radius,0.07\n',
#  'HpHp_L0.1_radius,0.07\n',
#  'HpHp_L0.01_radius,0.07\n',
#  'HpHp_L0.1_pcc,0.07\n',
#  'HH_L3_covariance,0.05\n',
#  'HH_L5_covariance,0.04\n',
#  'HH_jit_L0.1_variance,0.03\n',
#  'HH_jit_L0.01_variance,0.03\n',
#  'HH_L0.01_pcc,0.02\n',
#  'HH_jit_L1_variance,0.01\n',
#  'HH_L1_pcc,0.01\n',
#  'HH_L0.1_pcc,0.01\n',
#  'HH_L3_pcc,0.00\n',
#  'HH_L5_pcc,0.00\n',
#  'HH_L0.01_covariance,0.00\n',
#  'HH_jit_L5_variance,0.00\n',
#  'HH_jit_L3_variance,0.00\n']

# %% [markdown]
# **Model Training**

# %%
# Now creating a ____________ model
def create_model(input_dim):
    inp = Input(shape=(input_dim,))
    encoder = Dense(int(math.ceil(0.80 * input_dim)), activation="tanh")(inp)
    encoder = Dense(int(math.ceil(0.60 * input_dim)), activation="tanh")(encoder)
    encoder = Dense(int(math.ceil(0.40 * input_dim)), activation="tanh")(encoder)
    encoder = Dense(int(math.ceil(0.20 * input_dim)), activation="tanh")(encoder)
    decoder = Dense(int(math.ceil(0.40 * input_dim)), activation="tanh")(encoder)
    decoder = Dense(int(math.ceil(0.60 * input_dim)), activation="tanh")(decoder)
    decoder = Dense(int(math.ceil(0.80 * input_dim)), activation="tanh")(decoder)
    decoder = Dense(input_dim)(decoder)
    return Model(inp, decoder)

# %%
for top_n_features in [fisher_score_use_top_n_features]: # for loop runs only once. because there is a single item in the list only. The number
                           # describes the number of top features that shall be selected 
    #fs = [it['feature'] for it in scored[:top_n_features]] # fs is a list of feature names in order of decreasing
                                                           # F-score
    
    fs = []
    for it in scored[:top_n_features]:
      if it['score'] > use_features_with_fisher_score_greater_than:  
        fs.append(it['feature'])

    features_to_be_used = len(fs)
    print(features_to_be_used)
    #print(scored[:top_n_features])
    #print(fs)
    #print(type(fs))
    DF_BENIGN_TRAIN = scaled_df_known_device_benign_train[fs]
    DF_BENIGN_OPT = scaled_df_known_device_benign_opt[fs]
    DF_BENIGN_TEST = scaled_df_known_device_benign_test[fs]
    #print(type(DF_BENIGN_TRAIN))
    
    #model = create_model(top_n_features)
    model = create_model(len(fs))
    model.compile(loss="mean_squared_error",
                    optimizer="adam")
    
    Initial_Weights = model.get_weights()
    
    #checkpoint_filepath=f"/content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING-SimpleHomeCamera-{features_to_be_used}.h5"
    cp = ModelCheckpoint(filepath=checkpoint_filepath,
                                  monitor='val_loss',
                               save_best_only=True,
                               verbose=1)
    
    es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    start = time.time()
    epochs = 100
    history = model.fit(DF_BENIGN_TRAIN, DF_BENIGN_TRAIN,
                    epochs=epochs,
                    validation_data=(DF_BENIGN_OPT, DF_BENIGN_OPT),
                    verbose=1,
                    callbacks=[cp, es])
    
    end = time.time()
    print('time')
    print(end - start)
    print(model.summary())

## till here, we have created a model using X number of top features
# Out:
# 85
# Epoch 1/100
# 1831/1848 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00001: val_loss improved from inf to 0.00031, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 8s 4ms/step - loss: 0.0013 - val_loss: 3.1073e-04
# Epoch 2/100
# 1843/1848 [============================>.] - ETA: 0s - loss: 2.5624e-04
# Epoch 00002: val_loss improved from 0.00031 to 0.00022, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 7s 4ms/step - loss: 2.5621e-04 - val_loss: 2.2278e-04
# Epoch 3/100
# 1843/1848 [============================>.] - ETA: 0s - loss: 2.1718e-04
# Epoch 00003: val_loss did not improve from 0.00022
# 1848/1848 [==============================] - 6s 3ms/step - loss: 2.1727e-04 - val_loss: 2.8636e-04
# Epoch 4/100
# 1836/1848 [============================>.] - ETA: 0s - loss: 2.0754e-04
# Epoch 00004: val_loss improved from 0.00022 to 0.00022, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 7s 4ms/step - loss: 2.0743e-04 - val_loss: 2.2268e-04
# Epoch 5/100
# 1834/1848 [============================>.] - ETA: 0s - loss: 1.9844e-04
# Epoch 00005: val_loss did not improve from 0.00022
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.9819e-04 - val_loss: 2.5209e-04
# Epoch 6/100
# 1829/1848 [============================>.] - ETA: 0s - loss: 1.8391e-04
# Epoch 00006: val_loss did not improve from 0.00022
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.8418e-04 - val_loss: 2.2579e-04
# Epoch 7/100
# 1838/1848 [============================>.] - ETA: 0s - loss: 1.7190e-04
# Epoch 00007: val_loss improved from 0.00022 to 0.00018, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 7s 4ms/step - loss: 1.7178e-04 - val_loss: 1.8134e-04
# Epoch 8/100
# 1836/1848 [============================>.] - ETA: 0s - loss: 1.6651e-04
# Epoch 00008: val_loss improved from 0.00018 to 0.00016, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.6630e-04 - val_loss: 1.6004e-04
# Epoch 9/100
# 1844/1848 [============================>.] - ETA: 0s - loss: 1.5525e-04
# Epoch 00009: val_loss did not improve from 0.00016
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.5523e-04 - val_loss: 1.8695e-04
# Epoch 10/100
# 1846/1848 [============================>.] - ETA: 0s - loss: 1.4355e-04
# Epoch 00010: val_loss improved from 0.00016 to 0.00015, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.4352e-04 - val_loss: 1.5066e-04
# Epoch 11/100
# 1846/1848 [============================>.] - ETA: 0s - loss: 1.4236e-04
# Epoch 00011: val_loss did not improve from 0.00015
# 1848/1848 [==============================] - 6s 4ms/step - loss: 1.4233e-04 - val_loss: 1.6462e-04
# Epoch 12/100
# 1847/1848 [============================>.] - ETA: 0s - loss: 1.3399e-04
# Epoch 00012: val_loss improved from 0.00015 to 0.00014, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.3398e-04 - val_loss: 1.3510e-04
# Epoch 13/100
# 1847/1848 [============================>.] - ETA: 0s - loss: 1.2809e-04
# Epoch 00013: val_loss improved from 0.00014 to 0.00012, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.2808e-04 - val_loss: 1.2463e-04
# Epoch 14/100
# 1835/1848 [============================>.] - ETA: 0s - loss: 1.2238e-04
# Epoch 00014: val_loss did not improve from 0.00012
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.2215e-04 - val_loss: 1.3215e-04
# Epoch 15/100
# 1835/1848 [============================>.] - ETA: 0s - loss: 1.2066e-04
# Epoch 00015: val_loss did not improve from 0.00012
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.2055e-04 - val_loss: 1.3210e-04
# Epoch 16/100
# 1847/1848 [============================>.] - ETA: 0s - loss: 1.1548e-04
# Epoch 00016: val_loss did not improve from 0.00012
# 1848/1848 [==============================] - 6s 4ms/step - loss: 1.1548e-04 - val_loss: 1.4266e-04
# Epoch 17/100
# 1833/1848 [============================>.] - ETA: 0s - loss: 1.1235e-04
# Epoch 00017: val_loss did not improve from 0.00012
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.1223e-04 - val_loss: 1.8802e-04
# Epoch 18/100
# 1840/1848 [============================>.] - ETA: 0s - loss: 1.1439e-04
# Epoch 00018: val_loss improved from 0.00012 to 0.00012, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 7s 4ms/step - loss: 1.1423e-04 - val_loss: 1.1707e-04
# Epoch 19/100
# 1845/1848 [============================>.] - ETA: 0s - loss: 1.0837e-04
# Epoch 00019: val_loss improved from 0.00012 to 0.00011, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.0831e-04 - val_loss: 1.1053e-04
# Epoch 20/100
# 1840/1848 [============================>.] - ETA: 0s - loss: 1.0448e-04
# Epoch 00020: val_loss improved from 0.00011 to 0.00010, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 7s 4ms/step - loss: 1.0438e-04 - val_loss: 1.0352e-04
# Epoch 21/100
# 1834/1848 [============================>.] - ETA: 0s - loss: 1.0247e-04
# Epoch 00021: val_loss did not improve from 0.00010
# 1848/1848 [==============================] - 7s 4ms/step - loss: 1.0242e-04 - val_loss: 1.2101e-04
# Epoch 22/100
# 1839/1848 [============================>.] - ETA: 0s - loss: 1.0026e-04
# Epoch 00022: val_loss improved from 0.00010 to 0.00009, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 1848/1848 [==============================] - 7s 4ms/step - loss: 1.0024e-04 - val_loss: 9.0350e-05
# Epoch 23/100
# 1842/1848 [============================>.] - ETA: 0s - loss: 1.0547e-04
# Epoch 00023: val_loss did not improve from 0.00009
# 1848/1848 [==============================] - 6s 3ms/step - loss: 1.0539e-04 - val_loss: 9.4505e-05
# Epoch 24/100
# 1838/1848 [============================>.] - ETA: 0s - loss: 9.2255e-05
# Epoch 00024: val_loss did not improve from 0.00009
# 1848/1848 [==============================] - 6s 3ms/step - loss: 9.2212e-05 - val_loss: 1.1403e-04
# Epoch 25/100
# 1848/1848 [==============================] - ETA: 0s - loss: 9.6355e-05
# Epoch 00025: val_loss did not improve from 0.00009
# 1848/1848 [==============================] - 6s 4ms/step - loss: 9.6355e-05 - val_loss: 1.0038e-04
# Epoch 26/100
# 1840/1848 [============================>.] - ETA: 0s - loss: 9.4802e-05
# Epoch 00026: val_loss did not improve from 0.00009
# 1848/1848 [==============================] - 6s 4ms/step - loss: 9.4751e-05 - val_loss: 9.3463e-05
# Epoch 27/100
# 1847/1848 [============================>.] - ETA: 0s - loss: 9.2106e-05
# Epoch 00027: val_loss did not improve from 0.00009
# 1848/1848 [==============================] - 7s 4ms/step - loss: 9.2104e-05 - val_loss: 9.0449e-05
# time
# 173.27882647514343
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 85)]              0
#
#  dense_8 (Dense)             (None, 68)                5848
#
#  dense_9 (Dense)             (None, 51)                3519
#
#  dense_10 (Dense)            (None, 34)                1768
#
#  dense_11 (Dense)            (None, 17)                595
#
#  dense_12 (Dense)            (None, 34)                612
#
#  dense_13 (Dense)            (None, 51)                1785
#
#  dense_14 (Dense)            (None, 68)                3536
#
#  dense_15 (Dense)            (None, 85)                5865
#
# =================================================================
# Total params: 23,528
# Trainable params: 23,528
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Plotting the Training and Validation curves

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Opt'], loc='upper left')
plt.show()

# %% [markdown]
# **Defining an Error Threshold**

# %%
# above cell has successfully trained our model.
# 80% of the benign dataset has been consumed for training and validating the anomaly model.

# We shall use the remaining the 20% of the benign dataset to make an estimation of the reconstruction error of our autoencoder.

# Additionally, we shall only consume the feature columns which were used for the training.


df_benign_known_device_test_predictions = model.predict(scaled_df_known_device_benign_test[fs])

#print(df_benign_test_predictions)
# how can we substract a series from a dataframe?
#print("Type of the variable DF_BENIGN_TEST: " + str(type(DF_BENIGN_TEST)))
#print("Type of the variable DF_BENIGN_TEST_PREDICTIONS: " + str(type(df_benign_test_predictions)))
print("Shape of variable DF_BENIGN_TEST: " + str(scaled_df_known_device_benign_test[fs].shape))
print("Shape of variable DF_BENIGN_TEST_PREDICTIONS: " + str(df_benign_known_device_test_predictions.shape))
difference = scaled_df_known_device_benign_test[fs] - df_benign_known_device_test_predictions
print("Shape of the variable difference: " + str(difference.shape))

mse = np.mean(np.power(scaled_df_known_device_benign_test[fs] - df_benign_known_device_test_predictions, 2), axis=1) # Mean-Squared-Error is calculated for each row,
                                                                                # all ten feature values are used to generate a single error
                                                                                # number.
#print(type(mse))
#print("Shape of Mean-Squared-Error: " + str(mse.shape))
mean = mse.mean() # We calculate the mean of the whole series, that is the mean mse for all the benign test cases.
std = mse.std() # And we calculate the standard deviation of the mse series, containing only the test cases.

mse = pd.Series(mse)
print("MSE TYPE:    " + str(type(mse)))
print("MIN of MSE: " + str(mse.min()))
print("MAX of MSE: " + str(mse.max()))
print("MEAN of MSE: " + str(mean))
print("STD of MSE:  " + str(std))

mse_min = mse.min()
mse_max = mse.max()
print("\nMax Threshold = MSE_MAX: " + str(mse_max))

max_std_multiplier = int((mse_max - mean) / std)
print("\nMAX_STD_Multiplier = " + str(max_std_multiplier))
# Out:
# Shape of variable DF_BENIGN_TEST: (19703, 85)
# Shape of variable DF_BENIGN_TEST_PREDICTIONS: (19703, 85)
# Shape of the variable difference: (19703, 85)
# MSE TYPE:    <class 'pandas.core.series.Series'>
# MIN of MSE: 8.277829811185632e-06
# MAX of MSE: 0.07180124592422937
# MEAN of MSE: 9.116725109524392e-05
# STD of MSE:  0.0008996894576129724
#
# Max Threshold = MSE_MAX: 0.07180124592422937
#
# MAX_STD_Multiplier = 79

# %% [markdown]
# **Visualizing the error distribution of the test dataset**

# %%
mse_plot = mse.plot.hist(bins=20)
mse_plot.set_xlim((mse_min, mse_max))
mse_plot.set_ylim((0, mse[mse <= mse_max].count()))
# Out:
# (0.0, 19703.0)

# %%
# Identifying a quantile distribution on the basis that the records of large MSE maybe an anomaly.
# We postulate that records with MSE residing above the 95th percentile may be erroneous
# Attempting to find the STD Multiplier corresponding to the 95th percentile
#Anomaly Threshold percentile                                                
test_percentile = 1

quantile_mse = mse[mse <= mse.quantile(q=test_percentile)]  # <= is important here

print("MIN of QUANTILE_MSE: " + str(quantile_mse.min()))
print("MAX of QUANTILE_MSE: " + str(quantile_mse.max()))
print("MEAN of QUANTILE_MSE: " + str(quantile_mse.mean()))
print("STD of QUNATILE_MSE:  " + str(quantile_mse.std()))

print("Size of Series below 95th quantile: " + str(quantile_mse.size))

print("\nSuggested Minimum Threshold = QUANTILE_MSE_MAX: " + str(quantile_mse.max()))

min_std_multiplier = int((quantile_mse.max() - quantile_mse.mean()) / quantile_mse.std())
print("\nMIN_STD_Multiplier = " + str(min_std_multiplier))


quantile_mse_plot = quantile_mse.plot.hist(bins=20)
quantile_mse_plot.set_xlim((quantile_mse.min(), quantile_mse.max()))
quantile_mse_plot.set_ylim((0, quantile_mse[quantile_mse <= quantile_mse.max()].count()))

print(len(mse))
print(len(quantile_mse))
# Out:
# MIN of QUANTILE_MSE: 8.277829811185632e-06
# MAX of QUANTILE_MSE: 0.07180124592422937
# MEAN of QUANTILE_MSE: 9.116725109524392e-05
# STD of QUNATILE_MSE:  0.0008996894576129724
# Size of Series below 95th quantile: 19703
#
# Suggested Minimum Threshold = QUANTILE_MSE_MAX: 0.07180124592422937
#
# MIN_STD_Multiplier = 79
# 19703
# 19703

# %% [markdown]
# **Now lets evaluate the anomaly detection capability of this model on the known_device's own attack dataset**

# %%
 #A Class definition for executing predictions
class AnomalyModel:
    def __init__(self, model, threshold, scaler):
        self.model = model
        self.threshold = threshold
        self.scaler = scaler

    def predict(self, x):
        x_pred = self.model.predict(x)
        mse = np.mean(np.power(x - x_pred, 2), axis=1)
        y_pred = mse > self.threshold
        return y_pred.astype(int)

    #def scale_predict_classes(self, x):
    #    x = self.scaler.transform(x)
    #    y_pred = self.predict(x)
    #    classes_arr = []
    #    for e in y_pred:
    #        el = [0,0]
    #        el[e] = 1
    #        classes_arr.append(el)
    #    return np.array(classes_arr)

# %%
# Testing the accuracy of the anomaly model on the known_devices attack data

# While we have used the benign_test dataset to define a threshold, its unknown to the model itself since no parameters learnt have used values from this dataset.
# We shall thus use a random mix of benign_test dataset and the attack_dataset for our testing.

anomaly_detect_01_df_benign = scaled_df_known_device_benign_test[fs] # Creating Labeled datasets
anomaly_detect_01_df_benign['malicious'] = 0

# Removing randomness bias
# df_malicious = df_known_device_attack.sample(n=df_known_device_benign_test.shape[0], random_state=406)[fs] # Keeping equal parts of benign / malicious data
anomaly_detect_01_df_malicious = scaled_df_known_device_attack.sample(n=scaled_df_known_device_benign_test.shape[0])[fs] # Keeping equal parts of benign / malicious data
anomaly_detect_01_df_malicious['malicious'] = 1

anomaly_detect_01_df = anomaly_detect_01_df_benign.append(anomaly_detect_01_df_malicious)
anomaly_detect_01_X_test = anomaly_detect_01_df.drop(columns=['malicious']).values
anomaly_detect_01_Y_test = anomaly_detect_01_df['malicious'] # This shall form the ground truth series of values.
#print(Y_test)

for threshold in [mse_max, quantile_mse.max()]:
  m = AnomalyModel(model , threshold, scaler)
  anomaly_detect_01_Y_pred = m.predict(anomaly_detect_01_X_test)
  print('Test-----------------')
  #print(f'suggensted threshodl n {best_n}')
  print('Accuracy')
  anomaly_detect_01_acc = accuracy_score(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred)
  print(anomaly_detect_01_acc)
  print('Precision')
  anomaly_detect_01_prec = precision_score(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred)
  print(anomaly_detect_01_prec)
  print('CM')
  anomaly_detect_01_cm = confusion_matrix(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred, labels=[0,1])
  print(anomaly_detect_01_cm)  
  print(type(anomaly_detect_01_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_01_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Test-----------------
# Accuracy
# 0.6867735877785109
# Precision
# 1.0
# CM
# [[19703     0]
#  [12343  7360]]
# <class 'numpy.ndarray'>
# Test-----------------
# Accuracy
# 0.6867735877785109
# Precision
# 1.0
# CM
# [[19703     0]
#  [12343  7360]]
# <class 'numpy.ndarray'>

# %% [markdown]
# **Finding an anomaly threshold that maximises the accuracy and precision of the model**

# %%
print('Starting Accuracy')
starting_accuracy = anomaly_detect_01_acc
base_acc = anomaly_detect_01_acc
print(base_acc)
print('Starting Precision')
base_precision = anomaly_detect_01_prec
print(base_precision)

new_percentile = 0.995
#new_percentile = new_percentile - 0.005
some_increase_found = False

while True:
  if new_percentile <= 0.9:
    print("reached quite  low percentile of 0.90 ... Aborting")
    anomaly_detect_01_chosen_threshold = quantile_mse.max()
    print("selected percentile for threshold is 1.0")
    print("selected threshold is: " + str(anomaly_detect_01_chosen_threshold))    
    break
  threshold = mse[mse < mse.quantile(q=new_percentile)].max()
  print("Current Threshold: " + str(threshold))
  m = AnomalyModel(model, threshold, scaler)
  anomaly_detect_01_Y_pred = m.predict(anomaly_detect_01_X_test)
  new_acc = accuracy_score(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred)
  new_precision = precision_score(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred)
  print("new_acc: " + str(new_acc) + " ... new_precision: " + str(new_precision))
  if new_acc > base_acc:
    print("new_acc > base_acc")
    # saving old base for comparison later
    #old_acc = base_acc
    #old_precision = base_precision
    # defining new base 
    base_acc = new_acc
    base_precision = new_precision
    # decreasing percentile for next test
    new_percentile = new_percentile - 0.005
    print("Next Percentile to test " + str(new_percentile) + "\n-------------------\n")
    some_increase_found = True
  elif new_acc < base_acc:
    print("NEW-ACC < BASE-ACC")
    if some_increase_found:
      val = input("Accuracy has started to decrease, stop now? (y/n) ")
      if val == 'y':
        print("Phew... \n\n")
        print("selected percentile for threshold is: " + str(new_percentile + 0.005))
        print("selected threshold is: " + str(mse[mse < mse.quantile(q=(new_percentile + 0.005))].max()))
        anomaly_detect_01_chosen_threshold = mse[mse < mse.quantile(q=(new_percentile + 0.005))].max()
        break
    new_percentile = new_percentile - 0.005
    print("Next Percentile to test " + str(new_percentile))
    continue
  else:
    new_percentile = new_percentile - 0.005
    print("Next Percentile to test " + str(new_percentile))

if new_acc > starting_accuracy:
  print('CM')
  anomaly_detect_01_cm = confusion_matrix(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred, labels=[0,1])
  print(anomaly_detect_01_cm)  
  print(type(anomaly_detect_01_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_01_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
else:
  anomaly_detect_01_chosen_threshold = mse_max
  print("Chosen Threshold: " + str(anomaly_detect_01_chosen_threshold))
  print("This is MSE MAX")
  print('CM')
  anomaly_detect_01_cm = confusion_matrix(anomaly_detect_01_Y_test, anomaly_detect_01_Y_pred, labels=[0,1])
  print(anomaly_detect_01_cm)  
  print(type(anomaly_detect_01_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_01_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
# Out:
# Starting Accuracy
# 0.6867735877785109
# Starting Precision
# 1.0
# Current Threshold: 0.0012677922889164281
# new_acc: 0.6844896716236106 ... new_precision: 0.9867434386716658
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.99
# Current Threshold: 0.0006106693366196971
# new_acc: 0.6820281175455515 ... new_precision: 0.9738406658739596
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.985
# Current Threshold: 0.00044090510294925763
# new_acc: 0.9922600619195047 ... new_precision: 0.985192596298149
# new_acc > base_acc
# Next Percentile to test 0.98
# -------------------
#
# Current Threshold: 0.0003568880745063812
# new_acc: 0.9897477541491143 ... new_precision: 0.9802896819471405
# NEW-ACC < BASE-ACC
# Accuracy has started to decrease, stop now? (y/n) n
# Next Percentile to test 0.975
# Current Threshold: 0.00030890881811478516
# new_acc: 0.9873369537633863 ... new_precision: 0.9755348652931854
# NEW-ACC < BASE-ACC
# Accuracy has started to decrease, stop now? (y/n) y
# Phew...
#
#
# selected percentile for threshold is: 0.98
# selected threshold is: 0.0003568880745063812
# CM
# [[19209   494]
#  [    5 19698]]
# <class 'numpy.ndarray'>

# %% [markdown]
# # Now that we have a model of a known device, lets test it against an unknown device.
#
# In order to find the accuracy and precision of the data, we shall need both the benign and the malicious data, scaled to the originally learnt parameters.

# %%
Run_For_Malware_Mirai = 0
Run_For_Malware_Bashlite = 1

# %%
print("====-- Loading Benign Data --====\n")

filepaths = []
for device in Unknown_Devices:
  print(device)
  path = f"/content/drive/My Drive/thesis-unsub/data/{device}/benign_traffic.csv"
  filepaths.append(path)

df_unknown_device_benign = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)
print("\n Benign DataFrame Information\n------")
df_unknown_device_benign.info()


print("\n\n=========\n\n")


if Run_For_Malware_Mirai:
  print("====-- Loading Attack Data - Mirai --====\n")
  Mirai_Filepaths = []
  for device in Unknown_Devices:
    print(device)
    path = f"/content/drive/My Drive/thesis-unsub/data/{device}/mirai_attacks/"
    for files in ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']:
      filepath = path + str(files)
      Mirai_Filepaths.append(filepath)

  print(Mirai_Filepaths)

  df_unknown_device_attack= pd.concat((pd.read_csv(f) for f in Mirai_Filepaths), ignore_index=True)
  print("\n Malware DataFrame Information - Mirai\n------")
  df_unknown_device_attack.info()



if Run_For_Malware_Bashlite:
  Bashlite_Filepaths = []
  for device in Unknown_Devices:
    print(device)
    path = f"/content/drive/My Drive/thesis-unsub/data/{device}/gafgyt_attacks/"
    for files in ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']:
      filepath = path + str(files)
      Bashlite_Filepaths.append(filepath)

  print(Bashlite_Filepaths)

  df_unknown_device_attack = pd.concat((pd.read_csv(f) for f in Bashlite_Filepaths), ignore_index=True)
  print("\nDataFrame Information\n------")
  df_unknown_device_attack.info()
# Out:
# ====-- Loading Benign Data --====
#
# Ecobee_Thermostat
#
#  Benign DataFrame Information
# ------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13113 entries, 0 to 13112
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 11.5 MB
#
#
# =========
#
#
# Ecobee_Thermostat
# ['/content/drive/My Drive/thesis-unsub/data/Ecobee_Thermostat/gafgyt_attacks/combo.csv', '/content/drive/My Drive/thesis-unsub/data/Ecobee_Thermostat/gafgyt_attacks/junk.csv', '/content/drive/My Drive/thesis-unsub/data/Ecobee_Thermostat/gafgyt_attacks/scan.csv', '/content/drive/My Drive/thesis-unsub/data/Ecobee_Thermostat/gafgyt_attacks/tcp.csv', '/content/drive/My Drive/thesis-unsub/data/Ecobee_Thermostat/gafgyt_attacks/udp.csv']
#
# DataFrame Information
# ------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310630 entries, 0 to 310629
# Columns: 115 entries, MI_dir_L5_weight to HpHp_L0.01_pcc
# dtypes: float64(115)
# memory usage: 272.5 MB

# %% [markdown]
# Scaling unknown devices data.

# %%
# Scaling the unknown devices data to the parameters learnt during the scaling of the known devices data.

scaled_df_unknown_device_benign = scaler.transform(df_unknown_device_benign)
scaled_df_unknown_device_attack = scaler.transform(df_unknown_device_attack)


#Converting NumPy arrays back to Pandas DataFrames
scaled_df_unknown_device_benign = pd.DataFrame(scaled_df_unknown_device_benign, columns=col_list)
scaled_df_unknown_device_attack = pd.DataFrame(scaled_df_unknown_device_attack, columns=col_list)

# %%
scaled_df_unknown_device_attack['class'] = 'attack'
scaled_df_unknown_device_benign['class'] = 'benign'

# %% [markdown]
# **Now we need to simulate some observed behavior and some unknown behavior of benign data.**
#
# observed behavior is that small sample that we shall use for transfer learning.
#
# unknown behavior is that sample used to check accuracy of the model.

# %%
# sampling some data from the dataset. We shall sample this data to check if it improves the autoencoder accuracy.
# and splitting this data into three parts, for training, optimization and validation.

length_unknown_device_benign = len(scaled_df_unknown_device_benign)

# extracting a small sample for re-training the model
scaled_df_unknown_device_benign_sample, scaled_df_unknown_device_benign_remaining = np.split(scaled_df_unknown_device_benign.sample(frac=1), [int(0.10*length_unknown_device_benign)])


# splitting the small sample of data into train, opt and test datasets.
scaled_df_unknown_device_benign_sample_train, scaled_df_unknown_device_benign_sample_opt, scaled_df_unknown_device_benign_sample_test = np.split(scaled_df_unknown_device_benign_sample, [int(3/5*len(scaled_df_unknown_device_benign_sample)), int(4/5*len(scaled_df_unknown_device_benign_sample))])


print("INFORMATION ON SAMPLED DATA")
scaled_df_unknown_device_benign_sample.info()

print("\nINFORMATION ON REMAINING BENIGN DATA")
scaled_df_unknown_device_benign_remaining.info()

print("\nSAMPLE DATA SPLIT FOR TRAIN, OPT AND TEST")
scaled_df_unknown_device_benign_sample_train.info()
scaled_df_unknown_device_benign_sample_opt.info()
scaled_df_unknown_device_benign_sample_test.info()
# Out:
# INFORMATION ON SAMPLED DATA
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1311 entries, 10988 to 6768
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 1.2+ MB
#
# INFORMATION ON REMAINING BENIGN DATA
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11802 entries, 10818 to 7270
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 10.5+ MB
#
# SAMPLE DATA SPLIT FOR TRAIN, OPT AND TEST
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 786 entries, 10988 to 245
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 718.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 3837 to 7767
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 239.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263 entries, 2146 to 6768
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 240.4+ KB

# %% [markdown]
# **Time to calculate the Fisher Score, Hope to use this to build a picture on the difference in important features**
#
# Here we shall us only use the sampled data for fisher score calculation, since this is the only known informaiton.
#
# I did not observe much difference in the Fisher scores when comparing the use of a whole dataset or only the sampled dataset.

# %%
## Fisher Scoring, for Fisher scoring we shall use the attack data of the same devices
## for which we trained our benign model.

# Creating a Fisher dataframe that shall contain an equal mix of benign_train and attack data.
# Removing randomizing states. We shall have multiple runs and tabulation of results.
# scaled_df_fisher = scaled_df_known_device_benign_train.append(scaled_df_known_device_attack.sample(n=scaled_df_known_device_benign_train.shape[0], random_state=406))

# Using the whole dataset.
#unknown_scaled_df_fisher = scaled_df_unknown_device_benign.append(scaled_df_unknown_device_attack.sample(n=scaled_df_unknown_device_benign.shape[0]))

# Using only the sampled dataset.
unknown_scaled_df_fisher = scaled_df_unknown_device_benign_sample.append(scaled_df_unknown_device_attack.sample(n=scaled_df_unknown_device_benign_sample.shape[0]))

unknown_scaled_df_fisher.info()

unknown_scored = [] # declare a list
unknown_indices = {} # declare two dictionaries, purpose unknown
unknown_shps = {}
unknown_classes = ['benign','attack']

for cl in unknown_classes:
    unknown_indices[cl] = unknown_scaled_df_fisher['class'] == cl # Now here, above created Fisher dataframe shall have two classes only.
                                           # so half of the time the comparison output shall be true and false
                                           # for the rest.
                                           # It creates a Pandas series
    unknown_shps[cl] = unknown_scaled_df_fisher[unknown_indices[cl]].shape[0] # dictionary contains the number of rows of benign traffic and the
                                               # number of rows for the attack traffic

for col in unknown_scaled_df_fisher.columns: # Loop through all the columns of the Fisher DataFrame
    if col == 'class':  # if the column is that of "Class", then skip it.
        continue
    num = 0
    den = 0
    m = unknown_scaled_df_fisher[col].mean() # For the column under the current iteration, find the mean value.
                            # no, nothing strange about this. We are finding out the mean of each field/column
                            # in the dataset.
    
    for cl in classes: # For each column (this essentially means that we are considering that column at the moment)
                       # calculate the numerator and the denominator values for the Fisher score per class.
        num += (unknown_shps[cl] / unknown_scaled_df_fisher.shape[0]) * (m - unknown_scaled_df_fisher[unknown_indices[cl]][col].mean())**2
                # shps[cl] --> e.g if shps['benign'] then number of rows in it shall be 33032
                # (33032/66064) * ([mean-of-that-whole-column] - mean-of-rows-whose class was cl)**2
        den += (unknown_shps[cl] / unknown_scaled_df_fisher.shape[0]) * unknown_scaled_df_fisher[unknown_indices[cl]][col].var()
                # shps[cl] --> e.g if shps['benign'] then number of rows in it shall be 33032
                # (33032/66064) * (variance-of-rows-whose class was cl)
        
    unknown_score = {'feature': col, 'score': num / den}
    unknown_scored.append(unknown_score)
    #print(score)
unknown_scored.sort(key=lambda x: x['score'], reverse=True)
unknown_scored[:115] #scored is a list of dictionaries    


# Write down the calculated F-scores in a file.
with open(Unknown_F_Score_File, 'w+') as file:
    unknown_lines = ['Feature,Score\n']
    for s in unknown_scored:
        unknown_lines.append(s['feature'] + ',' + "{0:.2f}".format(s['score']) + '\n')
    file.writelines(unknown_lines)

unknown_lines
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2622 entries, 10988 to 304283
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 2.3+ MB
# ['Feature,Score\n',
#  'MI_dir_L0.01_mean,8.38\n',
#  'H_L0.01_mean,8.33\n',
#  'MI_dir_L0.01_variance,2.80\n',
#  'H_L0.01_variance,2.79\n',
#  'MI_dir_L0.1_mean,1.96\n',
#  'H_L0.1_mean,1.96\n',
#  'HpHp_L0.01_weight,1.38\n',
#  'HH_jit_L0.01_mean,1.29\n',
#  'HH_jit_L0.1_mean,1.26\n',
#  'HH_jit_L1_mean,1.11\n',
#  'HH_jit_L3_mean,1.08\n',
#  'HH_jit_L5_mean,1.08\n',
#  'HpHp_L0.01_magnitude,1.05\n',
#  'HH_L0.01_magnitude,1.04\n',
#  'HH_L0.01_std,1.01\n',
#  'HpHp_L0.01_std,1.00\n',
#  'HH_L0.01_mean,0.97\n',
#  'HpHp_L0.01_mean,0.94\n',
#  'HpHp_L0.1_magnitude,0.91\n',
#  'HH_L0.1_magnitude,0.89\n',
#  'HpHp_L1_magnitude,0.83\n',
#  'HH_L1_magnitude,0.81\n',
#  'HH_L0.1_mean,0.80\n',
#  'HpHp_L3_magnitude,0.79\n',
#  'HpHp_L0.1_mean,0.79\n',
#  'MI_dir_L1_mean,0.77\n',
#  'H_L1_mean,0.77\n',
#  'HH_L3_magnitude,0.77\n',
#  'HpHp_L5_magnitude,0.77\n',
#  'HH_L5_magnitude,0.75\n',
#  'MI_dir_L0.1_variance,0.70\n',
#  'H_L0.1_variance,0.70\n',
#  'HH_L1_mean,0.66\n',
#  'HpHp_L1_mean,0.66\n',
#  'HpHp_L0.1_std,0.65\n',
#  'HH_L0.1_std,0.65\n',
#  'MI_dir_L3_mean,0.53\n',
#  'H_L3_mean,0.53\n',
#  'HH_L3_mean,0.50\n',
#  'HpHp_L3_mean,0.50\n',
#  'HH_L0.01_radius,0.45\n',
#  'MI_dir_L5_mean,0.43\n',
#  'H_L5_mean,0.43\n',
#  'HpHp_L0.01_radius,0.43\n',
#  'HH_L5_mean,0.41\n',
#  'HpHp_L5_mean,0.41\n',
#  'HH_L1_std,0.31\n',
#  'HpHp_L1_std,0.31\n',
#  'HpHp_L3_std,0.26\n',
#  'HH_L3_std,0.26\n',
#  'HpHp_L1_weight,0.23\n',
#  'HpHp_L5_std,0.23\n',
#  'HH_L5_std,0.23\n',
#  'HpHp_L0.01_pcc,0.22\n',
#  'HpHp_L0.1_weight,0.22\n',
#  'HpHp_L0.1_radius,0.21\n',
#  'HH_L0.1_radius,0.21\n',
#  'MI_dir_L1_variance,0.20\n',
#  'H_L1_variance,0.20\n',
#  'MI_dir_L5_weight,0.20\n',
#  'H_L5_weight,0.20\n',
#  'MI_dir_L3_weight,0.20\n',
#  'H_L3_weight,0.20\n',
#  'MI_dir_L1_weight,0.19\n',
#  'H_L1_weight,0.19\n',
#  'MI_dir_L0.1_weight,0.18\n',
#  'H_L0.1_weight,0.18\n',
#  'HH_L1_radius,0.18\n',
#  'HpHp_L1_radius,0.18\n',
#  'HpHp_L3_weight,0.18\n',
#  'HpHp_L5_radius,0.17\n',
#  'HH_L5_radius,0.17\n',
#  'MI_dir_L0.01_weight,0.17\n',
#  'H_L0.01_weight,0.17\n',
#  'HpHp_L0.01_covariance,0.17\n',
#  'HpHp_L3_radius,0.16\n',
#  'HH_L3_radius,0.16\n',
#  'HH_jit_L3_weight,0.16\n',
#  'HH_L3_weight,0.16\n',
#  'HH_jit_L1_weight,0.16\n',
#  'HH_L1_weight,0.16\n',
#  'HH_L5_weight,0.16\n',
#  'HH_jit_L5_weight,0.16\n',
#  'HH_L0.1_weight,0.16\n',
#  'HH_jit_L0.1_weight,0.16\n',
#  'HpHp_L0.1_pcc,0.15\n',
#  'HH_L0.1_pcc,0.15\n',
#  'HH_L0.01_covariance,0.14\n',
#  'HH_jit_L0.01_weight,0.13\n',
#  'HH_L0.01_weight,0.13\n',
#  'MI_dir_L3_variance,0.11\n',
#  'H_L3_variance,0.11\n',
#  'HpHp_L5_weight,0.11\n',
#  'HpHp_L0.1_covariance,0.11\n',
#  'HH_L0.1_covariance,0.10\n',
#  'MI_dir_L5_variance,0.08\n',
#  'H_L5_variance,0.08\n',
#  'HpHp_L1_pcc,0.07\n',
#  'HH_L1_pcc,0.07\n',
#  'HH_L0.01_pcc,0.06\n',
#  'HpHp_L1_covariance,0.06\n',
#  'HH_L1_covariance,0.06\n',
#  'HpHp_L3_pcc,0.05\n',
#  'HH_L3_pcc,0.05\n',
#  'HpHp_L3_covariance,0.04\n',
#  'HH_L3_covariance,0.04\n',
#  'HpHp_L5_pcc,0.04\n',
#  'HH_L5_pcc,0.04\n',
#  'HpHp_L5_covariance,0.04\n',
#  'HH_L5_covariance,0.04\n',
#  'HH_jit_L0.1_variance,0.03\n',
#  'HH_jit_L0.01_variance,0.03\n',
#  'HH_jit_L1_variance,0.01\n',
#  'HH_jit_L5_variance,0.00\n',
#  'HH_jit_L3_variance,0.00\n']

# %% [markdown]
# **Attempting to find the difference between the two Fisher Score files, for Known devices and Unknown devices**

# %%
with open(Known_F_Score_File) as file_1:
    Known_F_Score_File_text = file_1.readlines()
  
with open(Unknown_F_Score_File) as file_2:
    Unknown_F_Score_File_text = file_2.readlines()
  
# Find and print the diff:
for line in difflib.unified_diff(
        Known_F_Score_File_text, Unknown_F_Score_File_text, fromfile=Known_F_Score_File, 
        tofile=Unknown_F_Score_File, lineterm=''):
    print(line)
# Out:
# --- /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Fisher-Scores/Known-SimpleHomeCamera_Unknown-Provision-A-0.1.csv
# +++ /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Fisher-Scores/Known-SimpleHomeCamera_Unknown-Provision-B-0.1.csv
# @@ -1,116 +1,116 @@
#  Feature,Score
#
# -H_L0.01_mean,1.15
#
# -MI_dir_L0.01_mean,1.15
#
# -HH_jit_L0.01_mean,1.13
#
# -HH_jit_L0.1_mean,1.11
#
# -HH_jit_L1_mean,0.98
#
# -HH_jit_L3_mean,0.96
#
# -HH_jit_L5_mean,0.96
#
# -H_L0.1_mean,0.65
#
# -MI_dir_L0.1_mean,0.65
#
# -H_L0.01_variance,0.59
#
# -MI_dir_L0.01_variance,0.59
#
# -HH_L0.01_magnitude,0.48
#
# -HH_L0.01_mean,0.41
#
# -HH_L0.01_std,0.38
#
# -MI_dir_L1_mean,0.37
#
# -H_L1_mean,0.37
#
# -HH_L0.1_magnitude,0.36
#
# -HH_L0.1_mean,0.33
#
# -H_L0.1_variance,0.32
#
# -MI_dir_L0.1_variance,0.32
#
# -MI_dir_L3_mean,0.31
#
# -H_L3_mean,0.31
#
# -HH_L1_magnitude,0.29
#
# -MI_dir_L5_mean,0.29
#
# -H_L5_mean,0.29
#
# -HH_L1_mean,0.28
#
# -HH_L3_magnitude,0.26
#
# -HH_L0.01_radius,0.26
#
# -HH_L3_mean,0.26
#
# -HH_L0.1_std,0.26
#
# -HH_L5_mean,0.26
#
# -HH_L5_magnitude,0.25
#
# -HH_L1_std,0.20
#
# -MI_dir_L0.1_weight,0.20
#
# -H_L0.1_weight,0.20
#
# -MI_dir_L1_weight,0.20
#
# -H_L1_weight,0.20
#
# -HpHp_L1_weight,0.20
#
# -HH_L0.1_radius,0.20
#
# -HH_L3_std,0.19
#
# -MI_dir_L1_variance,0.18
#
# -H_L1_variance,0.18
#
# -MI_dir_L3_weight,0.18
#
# -H_L3_weight,0.18
#
# -HH_L5_std,0.18
#
# -HH_jit_L0.1_weight,0.18
#
# -HH_L0.1_weight,0.18
#
# +MI_dir_L0.01_mean,8.38
#
# +H_L0.01_mean,8.33
#
# +MI_dir_L0.01_variance,2.80
#
# +H_L0.01_variance,2.79
#
# +MI_dir_L0.1_mean,1.96
#
# +H_L0.1_mean,1.96
#
# +HpHp_L0.01_weight,1.38
#
# +HH_jit_L0.01_mean,1.29
#
# +HH_jit_L0.1_mean,1.26
#
# +HH_jit_L1_mean,1.11
#
# +HH_jit_L3_mean,1.08
#
# +HH_jit_L5_mean,1.08
#
# +HpHp_L0.01_magnitude,1.05
#
# +HH_L0.01_magnitude,1.04
#
# +HH_L0.01_std,1.01
#
# +HpHp_L0.01_std,1.00
#
# +HH_L0.01_mean,0.97
#
# +HpHp_L0.01_mean,0.94
#
# +HpHp_L0.1_magnitude,0.91
#
# +HH_L0.1_magnitude,0.89
#
# +HpHp_L1_magnitude,0.83
#
# +HH_L1_magnitude,0.81
#
# +HH_L0.1_mean,0.80
#
# +HpHp_L3_magnitude,0.79
#
# +HpHp_L0.1_mean,0.79
#
# +MI_dir_L1_mean,0.77
#
# +H_L1_mean,0.77
#
# +HH_L3_magnitude,0.77
#
# +HpHp_L5_magnitude,0.77
#
# +HH_L5_magnitude,0.75
#
# +MI_dir_L0.1_variance,0.70
#
# +H_L0.1_variance,0.70
#
# +HH_L1_mean,0.66
#
# +HpHp_L1_mean,0.66
#
# +HpHp_L0.1_std,0.65
#
# +HH_L0.1_std,0.65
#
# +MI_dir_L3_mean,0.53
#
# +H_L3_mean,0.53
#
# +HH_L3_mean,0.50
#
# +HpHp_L3_mean,0.50
#
# +HH_L0.01_radius,0.45
#
# +MI_dir_L5_mean,0.43
#
# +H_L5_mean,0.43
#
# +HpHp_L0.01_radius,0.43
#
# +HH_L5_mean,0.41
#
# +HpHp_L5_mean,0.41
#
# +HH_L1_std,0.31
#
# +HpHp_L1_std,0.31
#
# +HpHp_L3_std,0.26
#
# +HH_L3_std,0.26
#
# +HpHp_L1_weight,0.23
#
# +HpHp_L5_std,0.23
#
# +HH_L5_std,0.23
#
# +HpHp_L0.01_pcc,0.22
#
# +HpHp_L0.1_weight,0.22
#
# +HpHp_L0.1_radius,0.21
#
# +HH_L0.1_radius,0.21
#
# +MI_dir_L1_variance,0.20
#
# +H_L1_variance,0.20
#
# +MI_dir_L5_weight,0.20
#
# +H_L5_weight,0.20
#
# +MI_dir_L3_weight,0.20
#
# +H_L3_weight,0.20
#
# +MI_dir_L1_weight,0.19
#
# +H_L1_weight,0.19
#
# +MI_dir_L0.1_weight,0.18
#
# +H_L0.1_weight,0.18
#
# +HH_L1_radius,0.18
#
# +HpHp_L1_radius,0.18
#
# +HpHp_L3_weight,0.18
#
# +HpHp_L5_radius,0.17
#
# +HH_L5_radius,0.17
#
#  MI_dir_L0.01_weight,0.17
#
#  H_L0.01_weight,0.17
#
# -HH_jit_L1_weight,0.17
#
# -HH_L1_weight,0.17
#
# -HH_L1_radius,0.17
#
# -MI_dir_L5_weight,0.17
#
# -H_L5_weight,0.17
#
# -HpHp_L0.01_mean,0.16
#
# -HpHp_L1_mean,0.16
#
# -HpHp_L3_mean,0.16
#
# -HpHp_L5_mean,0.16
#
# -HpHp_L0.1_weight,0.16
#
# -HpHp_L0.1_mean,0.16
#
# +HpHp_L0.01_covariance,0.17
#
# +HpHp_L3_radius,0.16
#
#  HH_L3_radius,0.16
#
# -HpHp_L3_weight,0.16
#
# -HpHp_L0.01_magnitude,0.15
#
# -HpHp_L0.1_magnitude,0.15
#
# -HH_L5_radius,0.15
#
# -HpHp_L1_magnitude,0.15
#
# -HpHp_L3_magnitude,0.15
#
# -HpHp_L5_magnitude,0.15
#
# -HH_jit_L3_weight,0.15
#
# -HH_L3_weight,0.15
#
# -HpHp_L5_weight,0.15
#
# -MI_dir_L3_variance,0.14
#
# -H_L3_variance,0.14
#
# -HH_L0.01_weight,0.14
#
# -HH_jit_L0.01_weight,0.14
#
# -MI_dir_L5_variance,0.14
#
# -H_L5_variance,0.14
#
# -HH_jit_L5_weight,0.14
#
# -HH_L5_weight,0.14
#
# -HpHp_L0.01_std,0.12
#
# -HpHp_L0.1_std,0.12
#
# -HpHp_L1_std,0.11
#
# -HpHp_L3_std,0.11
#
# -HH_L0.1_covariance,0.11
#
# -HpHp_L5_std,0.11
#
# -HpHp_L3_pcc,0.07
#
# +HH_jit_L3_weight,0.16
#
# +HH_L3_weight,0.16
#
# +HH_jit_L1_weight,0.16
#
# +HH_L1_weight,0.16
#
# +HH_L5_weight,0.16
#
# +HH_jit_L5_weight,0.16
#
# +HH_L0.1_weight,0.16
#
# +HH_jit_L0.1_weight,0.16
#
# +HpHp_L0.1_pcc,0.15
#
# +HH_L0.1_pcc,0.15
#
# +HH_L0.01_covariance,0.14
#
# +HH_jit_L0.01_weight,0.13
#
# +HH_L0.01_weight,0.13
#
# +MI_dir_L3_variance,0.11
#
# +H_L3_variance,0.11
#
# +HpHp_L5_weight,0.11
#
# +HpHp_L0.1_covariance,0.11
#
# +HH_L0.1_covariance,0.10
#
# +MI_dir_L5_variance,0.08
#
# +H_L5_variance,0.08
#
#  HpHp_L1_pcc,0.07
#
# -HpHp_L5_pcc,0.07
#
# -HpHp_L0.01_pcc,0.07
#
# -HpHp_L0.01_weight,0.07
#
# -HpHp_L0.1_covariance,0.07
#
# -HpHp_L1_covariance,0.07
#
# -HpHp_L3_covariance,0.07
#
# -HpHp_L5_covariance,0.07
#
# -HpHp_L0.01_covariance,0.07
#
# -HpHp_L1_radius,0.07
#
# -HpHp_L3_radius,0.07
#
# -HH_L1_covariance,0.07
#
# -HpHp_L5_radius,0.07
#
# -HpHp_L0.1_radius,0.07
#
# -HpHp_L0.01_radius,0.07
#
# -HpHp_L0.1_pcc,0.07
#
# -HH_L3_covariance,0.05
#
# +HH_L1_pcc,0.07
#
# +HH_L0.01_pcc,0.06
#
# +HpHp_L1_covariance,0.06
#
# +HH_L1_covariance,0.06
#
# +HpHp_L3_pcc,0.05
#
# +HH_L3_pcc,0.05
#
# +HpHp_L3_covariance,0.04
#
# +HH_L3_covariance,0.04
#
# +HpHp_L5_pcc,0.04
#
# +HH_L5_pcc,0.04
#
# +HpHp_L5_covariance,0.04
#
#  HH_L5_covariance,0.04
#
#  HH_jit_L0.1_variance,0.03
#
#  HH_jit_L0.01_variance,0.03
#
# -HH_L0.01_pcc,0.02
#
#  HH_jit_L1_variance,0.01
#
# -HH_L1_pcc,0.01
#
# -HH_L0.1_pcc,0.01
#
# -HH_L3_pcc,0.00
#
# -HH_L5_pcc,0.00
#
# -HH_L0.01_covariance,0.00
#
#  HH_jit_L5_variance,0.00
#
#  HH_jit_L3_variance,0.00

# %% [markdown]
# **Checking the performance of the original model against an unknown device.**
#
# Using the sampled unknown device here as well, since we are simulating a scenario where this is the known data only.

# %%
# Testing the accuracy of the anomaly model on the known_devices attack data

# While we have used the benign_test dataset to define a threshold, its unknown to the model itself since no parameters learnt have used values from this dataset.
# We shall thus use a random mix of benign_test dataset and the attack_dataset for our testing.

anomaly_detect_02_unknown_df_benign = scaled_df_unknown_device_benign_sample[fs] # "fs" is a list containing all the top features (based on Fisher score) of the old device. #Creating Labeled datasets 
anomaly_detect_02_unknown_df_benign['malicious'] = 0

# Removing randomness bias
# df_malicious = df_known_device_attack.sample(n=df_known_device_benign_test.shape[0], random_state=406)[fs] # Keeping equal parts of benign / malicious data
anomaly_detect_02_unknown_df_malicious = scaled_df_unknown_device_attack.sample(n=scaled_df_unknown_device_benign_sample.shape[0])[fs] # Keeping equal parts of benign / malicious data
anomaly_detect_02_unknown_df_malicious['malicious'] = 1

anomaly_detect_02_df = anomaly_detect_02_unknown_df_benign.append(anomaly_detect_02_unknown_df_malicious)
anomaly_detect_02_unknown_X_test = anomaly_detect_02_df.drop(columns=['malicious']).values
anomaly_detect_02_unknown_Y_test = anomaly_detect_02_df['malicious'] # This shall form the ground truth series of values.
#print(Y_test)

#print(unknown_X_test_scaled.shape)
#print(unknown_Y_test.shape)

for threshold in [anomaly_detect_01_chosen_threshold]:
  print("Threshold: " + str(threshold))
  m = AnomalyModel(model , threshold, scaler)
  anomaly_detect_02_unknown_Y_pred = m.predict(anomaly_detect_02_unknown_X_test)
  print('Test-----------------')
  #print(f'suggensted threshodl n {best_n}')
  print('Accuracy')
  anomaly_detect_02_acc = accuracy_score(anomaly_detect_02_unknown_Y_test, anomaly_detect_02_unknown_Y_pred)
  print(anomaly_detect_02_acc)
  print('Precision')
  print(precision_score(anomaly_detect_02_unknown_Y_test, anomaly_detect_02_unknown_Y_pred))
  print('CM')
  anomaly_detect_02_cm = confusion_matrix(anomaly_detect_02_unknown_Y_test, anomaly_detect_02_unknown_Y_pred, labels=[0,1])
  print(anomaly_detect_02_cm)  
  print(type(anomaly_detect_02_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_02_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
# Out:
# Threshold: 0.0003568880745063812
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Test-----------------
# Accuracy
# 0.534324942791762
# Precision
# 0.5177725118483413
# CM
# [[  90 1221]
#  [   0 1311]]
# <class 'numpy.ndarray'>

# %% [markdown]
# **We see that the acuracy of the model has decreased.**

# %% [markdown]
# **Attempting Transfer Learning**
# We shall attempt to replace the inner most layers of the autoencoder while keeping the other layers locked.

# %%
for layer in model.layers:
  #layer.trainable = True
  print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7fa8ed988490> True
# <keras.layers.core.dense.Dense object at 0x7fa8ed9c5890> True
# <keras.layers.core.dense.Dense object at 0x7fa8ed988510> True
# <keras.layers.core.dense.Dense object at 0x7fa8ed91e310> True
# <keras.layers.core.dense.Dense object at 0x7fa8e5671c50> True
# <keras.layers.core.dense.Dense object at 0x7fa8e8b550d0> True
# <keras.layers.core.dense.Dense object at 0x7fa8e86cfb10> True
# <keras.layers.core.dense.Dense object at 0x7fa8e566b190> True
# <keras.layers.core.dense.Dense object at 0x7fa8e87c9ad0> True

# %% [markdown]
# **We should make a copy of the original model and make changes to it ...**

# %%
# making a copy of the original model

transfer_model = model

# Freezing all layers except the three inner most layers.

for layer in transfer_model.layers[0:3]:
  layer.trainable = False

for layer in transfer_model.layers[-3:]:
  layer.trainable = False

for layer in transfer_model.layers[:]:
  print(layer, layer.trainable)

## Re-Initialization of layers in the center
initializer = keras.initializers.GlorotUniform()
#s = K.get_session()
for layer in transfer_model.layers[3:6]:
  #layer.kernel.initializer.run(session=s)
  layer.set_weights([initializer(shape=w.shape) for w in layer.get_weights()])
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7fa8ed988490> False
# <keras.layers.core.dense.Dense object at 0x7fa8ed9c5890> False
# <keras.layers.core.dense.Dense object at 0x7fa8ed988510> False
# <keras.layers.core.dense.Dense object at 0x7fa8ed91e310> True
# <keras.layers.core.dense.Dense object at 0x7fa8e5671c50> True
# <keras.layers.core.dense.Dense object at 0x7fa8e8b550d0> True
# <keras.layers.core.dense.Dense object at 0x7fa8e86cfb10> False
# <keras.layers.core.dense.Dense object at 0x7fa8e566b190> False
# <keras.layers.core.dense.Dense object at 0x7fa8e87c9ad0> False

# %% [markdown]
# **we need to be careful on using the same number of features on which the earlier model is built**

# %%
print(len(fs))
print(transfer_model.layers[0].input_shape[0][1])
# Out:
# 85
# 85

# %%
# Here cap the max number of features to be used o be equal to the input layer of the previous model.

max_features = transfer_model.layers[0].input_shape[0][1]
for top_n_features in [max_features]: # for loop runs only once. because there is a single item in the list only. The number
                           # describes the number of top features that shall be selected 
    #fs = [it['feature'] for it in scored[:top_n_features]] # fs is a list of feature names in order of decreasing
                                                           # F-score
    
    unknown_fs = []
    for it in unknown_scored[:top_n_features]:
      #if it['score'] > use_features_with_fisher_score_greater_than:  
        unknown_fs.append(it['feature'])

    features_to_be_used = len(unknown_fs)
    print(features_to_be_used)

    DF_UNKNOWN_BENIGN_TRAIN = scaled_df_unknown_device_benign_sample_train[unknown_fs]
    DF_UNKNOWN_BENIGN_OPT = scaled_df_unknown_device_benign_sample_opt[unknown_fs]
    DF_UNKNOWN_BENIGN_TEST = scaled_df_unknown_device_benign_sample_test[unknown_fs]


    
    #checkpoint_filepath=f"/content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING-SimpleHomeCamera-{features_to_be_used}.h5"
    transfer_cp = ModelCheckpoint(filepath=transfer_learning_checkpoint_filepath,
                                  monitor='val_loss',
                               save_best_only=True,
                               verbose=1)
    
    transfer_es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    start = time.time()
    epochs = 100
    transfer_history = transfer_model.fit(DF_UNKNOWN_BENIGN_TRAIN, DF_UNKNOWN_BENIGN_TRAIN,
                    epochs=epochs,
                    validation_data=(DF_UNKNOWN_BENIGN_OPT, DF_UNKNOWN_BENIGN_OPT),
                    verbose=1,
                    callbacks=[transfer_cp, transfer_es])
    
    end = time.time()
    print('time')
    print(end - start)
    print(transfer_model.summary())

## till here, we have created a model using X number of top features
# Out:
# 85
# Epoch 1/100
# 13/25 [==============>...............] - ETA: 0s - loss: 0.0353
# Epoch 00001: val_loss improved from inf to 0.00490, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 0.0224 - val_loss: 0.0049
# Epoch 2/100
# 16/25 [==================>...........] - ETA: 0s - loss: 0.0041
# Epoch 00002: val_loss improved from 0.00490 to 0.00206, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 3/100
# 17/25 [===================>..........] - ETA: 0s - loss: 0.0023
# Epoch 00003: val_loss improved from 0.00206 to 0.00160, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 4/100
# 15/25 [=================>............] - ETA: 0s - loss: 0.0017
# Epoch 00004: val_loss improved from 0.00160 to 0.00138, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 5/100
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0013
# Epoch 00005: val_loss improved from 0.00138 to 0.00123, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 6/100
# 14/25 [===============>..............] - ETA: 0s - loss: 0.0011
# Epoch 00006: val_loss improved from 0.00123 to 0.00118, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 7/100
# 18/25 [====================>.........] - ETA: 0s - loss: 0.0011
# Epoch 00007: val_loss improved from 0.00118 to 0.00106, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 8/100
# 14/25 [===============>..............] - ETA: 0s - loss: 8.9191e-04
# Epoch 00008: val_loss improved from 0.00106 to 0.00096, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 8.9847e-04 - val_loss: 9.6270e-04
# Epoch 9/100
# 14/25 [===============>..............] - ETA: 0s - loss: 8.1047e-04
# Epoch 00009: val_loss improved from 0.00096 to 0.00090, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 8.2313e-04 - val_loss: 9.0004e-04
# Epoch 10/100
# 17/25 [===================>..........] - ETA: 0s - loss: 7.2168e-04
# Epoch 00010: val_loss improved from 0.00090 to 0.00086, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 7.4209e-04 - val_loss: 8.5859e-04
# Epoch 11/100
# 16/25 [==================>...........] - ETA: 0s - loss: 6.8526e-04
# Epoch 00011: val_loss did not improve from 0.00086
# 25/25 [==============================] - 0s 5ms/step - loss: 6.7123e-04 - val_loss: 8.5894e-04
# Epoch 12/100
# 18/25 [====================>.........] - ETA: 0s - loss: 6.5959e-04
# Epoch 00012: val_loss improved from 0.00086 to 0.00077, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 6.7265e-04 - val_loss: 7.7277e-04
# Epoch 13/100
# 19/25 [=====================>........] - ETA: 0s - loss: 5.7673e-04
# Epoch 00013: val_loss did not improve from 0.00077
# 25/25 [==============================] - 0s 4ms/step - loss: 6.0177e-04 - val_loss: 7.9705e-04
# Epoch 14/100
# 21/25 [========================>.....] - ETA: 0s - loss: 5.9123e-04
# Epoch 00014: val_loss improved from 0.00077 to 0.00071, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 5.8397e-04 - val_loss: 7.1485e-04
# Epoch 15/100
# 18/25 [====================>.........] - ETA: 0s - loss: 5.3101e-04
# Epoch 00015: val_loss did not improve from 0.00071
# 25/25 [==============================] - 0s 4ms/step - loss: 5.5743e-04 - val_loss: 7.5104e-04
# Epoch 16/100
# 20/25 [=======================>......] - ETA: 0s - loss: 5.1573e-04
# Epoch 00016: val_loss did not improve from 0.00071
# 25/25 [==============================] - 0s 4ms/step - loss: 5.1463e-04 - val_loss: 7.8642e-04
# Epoch 17/100
# 21/25 [========================>.....] - ETA: 0s - loss: 5.1181e-04
# Epoch 00017: val_loss improved from 0.00071 to 0.00069, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 5.1963e-04 - val_loss: 6.9299e-04
# Epoch 18/100
# 14/25 [===============>..............] - ETA: 0s - loss: 4.5510e-04
# Epoch 00018: val_loss improved from 0.00069 to 0.00065, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 4.6945e-04 - val_loss: 6.5432e-04
# Epoch 19/100
# 19/25 [=====================>........] - ETA: 0s - loss: 4.5539e-04
# Epoch 00019: val_loss improved from 0.00065 to 0.00062, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 4.3851e-04 - val_loss: 6.2470e-04
# Epoch 20/100
# 15/25 [=================>............] - ETA: 0s - loss: 3.6053e-04
# Epoch 00020: val_loss did not improve from 0.00062
# 25/25 [==============================] - 0s 5ms/step - loss: 4.1944e-04 - val_loss: 6.2762e-04
# Epoch 21/100
# 19/25 [=====================>........] - ETA: 0s - loss: 4.3075e-04
# Epoch 00021: val_loss improved from 0.00062 to 0.00059, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 4.0020e-04 - val_loss: 5.9389e-04
# Epoch 22/100
# 13/25 [==============>...............] - ETA: 0s - loss: 4.4360e-04
# Epoch 00022: val_loss improved from 0.00059 to 0.00058, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 4.0200e-04 - val_loss: 5.7522e-04
# Epoch 23/100
# 19/25 [=====================>........] - ETA: 0s - loss: 3.6510e-04
# Epoch 00023: val_loss improved from 0.00058 to 0.00057, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 3.6129e-04 - val_loss: 5.6688e-04
# Epoch 24/100
# 19/25 [=====================>........] - ETA: 0s - loss: 3.2936e-04
# Epoch 00024: val_loss improved from 0.00057 to 0.00056, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 3.4715e-04 - val_loss: 5.5689e-04
# Epoch 25/100
# 20/25 [=======================>......] - ETA: 0s - loss: 3.2115e-04
# Epoch 00025: val_loss did not improve from 0.00056
# 25/25 [==============================] - 0s 4ms/step - loss: 3.3369e-04 - val_loss: 5.6013e-04
# Epoch 26/100
# 20/25 [=======================>......] - ETA: 0s - loss: 3.3319e-04
# Epoch 00026: val_loss improved from 0.00056 to 0.00054, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 3.3183e-04 - val_loss: 5.4098e-04
# Epoch 27/100
# 21/25 [========================>.....] - ETA: 0s - loss: 3.0709e-04
# Epoch 00027: val_loss improved from 0.00054 to 0.00053, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 3.1979e-04 - val_loss: 5.3070e-04
# Epoch 28/100
# 15/25 [=================>............] - ETA: 0s - loss: 3.2816e-04
# Epoch 00028: val_loss did not improve from 0.00053
# 25/25 [==============================] - 0s 5ms/step - loss: 3.2878e-04 - val_loss: 5.5653e-04
# Epoch 29/100
# 19/25 [=====================>........] - ETA: 0s - loss: 3.2164e-04
# Epoch 00029: val_loss improved from 0.00053 to 0.00051, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 3.1134e-04 - val_loss: 5.1222e-04
# Epoch 30/100
# 19/25 [=====================>........] - ETA: 0s - loss: 3.3413e-04
# Epoch 00030: val_loss did not improve from 0.00051
# 25/25 [==============================] - 0s 4ms/step - loss: 3.1724e-04 - val_loss: 5.3885e-04
# Epoch 31/100
# 20/25 [=======================>......] - ETA: 0s - loss: 3.0463e-04
# Epoch 00031: val_loss improved from 0.00051 to 0.00051, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 3.0033e-04 - val_loss: 5.0758e-04
# Epoch 32/100
# 15/25 [=================>............] - ETA: 0s - loss: 2.9476e-04
# Epoch 00032: val_loss did not improve from 0.00051
# 25/25 [==============================] - 0s 5ms/step - loss: 2.8754e-04 - val_loss: 5.3679e-04
# Epoch 33/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.8537e-04
# Epoch 00033: val_loss did not improve from 0.00051
# 25/25 [==============================] - 0s 5ms/step - loss: 2.8751e-04 - val_loss: 5.0820e-04
# Epoch 34/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.8589e-04
# Epoch 00034: val_loss improved from 0.00051 to 0.00049, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.7848e-04 - val_loss: 4.9042e-04
# Epoch 35/100
# 18/25 [====================>.........] - ETA: 0s - loss: 2.4984e-04
# Epoch 00035: val_loss did not improve from 0.00049
# 25/25 [==============================] - 0s 5ms/step - loss: 2.6193e-04 - val_loss: 4.9754e-04
# Epoch 36/100
# 17/25 [===================>..........] - ETA: 0s - loss: 2.9905e-04
# Epoch 00036: val_loss improved from 0.00049 to 0.00049, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.7776e-04 - val_loss: 4.8773e-04
# Epoch 37/100
# 17/25 [===================>..........] - ETA: 0s - loss: 2.7527e-04
# Epoch 00037: val_loss improved from 0.00049 to 0.00049, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.7808e-04 - val_loss: 4.8543e-04
# Epoch 38/100
# 17/25 [===================>..........] - ETA: 0s - loss: 2.7839e-04
# Epoch 00038: val_loss did not improve from 0.00049
# 25/25 [==============================] - 0s 5ms/step - loss: 2.5676e-04 - val_loss: 4.8631e-04
# Epoch 39/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.3842e-04
# Epoch 00039: val_loss improved from 0.00049 to 0.00047, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.5762e-04 - val_loss: 4.7298e-04
# Epoch 40/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.4331e-04
# Epoch 00040: val_loss improved from 0.00047 to 0.00047, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.4849e-04 - val_loss: 4.7112e-04
# Epoch 41/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.5554e-04
# Epoch 00041: val_loss did not improve from 0.00047
# 25/25 [==============================] - 0s 5ms/step - loss: 2.5382e-04 - val_loss: 5.0015e-04
# Epoch 42/100
# 18/25 [====================>.........] - ETA: 0s - loss: 2.3577e-04
# Epoch 00042: val_loss did not improve from 0.00047
# 25/25 [==============================] - 0s 5ms/step - loss: 2.3880e-04 - val_loss: 4.7312e-04
# Epoch 43/100
# 16/25 [==================>...........] - ETA: 0s - loss: 2.4394e-04
# Epoch 00043: val_loss improved from 0.00047 to 0.00046, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 2.3438e-04 - val_loss: 4.6242e-04
# Epoch 44/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.4443e-04
# Epoch 00044: val_loss did not improve from 0.00046
# 25/25 [==============================] - 0s 5ms/step - loss: 2.3767e-04 - val_loss: 4.6609e-04
# Epoch 45/100
# 18/25 [====================>.........] - ETA: 0s - loss: 2.3830e-04
# Epoch 00045: val_loss did not improve from 0.00046
# 25/25 [==============================] - 0s 4ms/step - loss: 2.3158e-04 - val_loss: 4.8760e-04
# Epoch 46/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.4918e-04
# Epoch 00046: val_loss did not improve from 0.00046
# 25/25 [==============================] - 0s 5ms/step - loss: 2.4317e-04 - val_loss: 4.6834e-04
# Epoch 47/100
# 16/25 [==================>...........] - ETA: 0s - loss: 2.2246e-04
# Epoch 00047: val_loss improved from 0.00046 to 0.00046, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 2.3108e-04 - val_loss: 4.6006e-04
# Epoch 48/100
# 16/25 [==================>...........] - ETA: 0s - loss: 2.1583e-04
# Epoch 00048: val_loss did not improve from 0.00046
# 25/25 [==============================] - 0s 5ms/step - loss: 2.2097e-04 - val_loss: 4.6010e-04
# Epoch 49/100
# 20/25 [=======================>......] - ETA: 0s - loss: 2.1602e-04
# Epoch 00049: val_loss improved from 0.00046 to 0.00046, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.1219e-04 - val_loss: 4.5865e-04
# Epoch 50/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.4065e-04
# Epoch 00050: val_loss improved from 0.00046 to 0.00046, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 2.2739e-04 - val_loss: 4.5671e-04
# Epoch 51/100
# 19/25 [=====================>........] - ETA: 0s - loss: 2.0475e-04
# Epoch 00051: val_loss improved from 0.00046 to 0.00045, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 7ms/step - loss: 2.0966e-04 - val_loss: 4.5137e-04
# Epoch 52/100
# 16/25 [==================>...........] - ETA: 0s - loss: 2.0127e-04
# Epoch 00052: val_loss improved from 0.00045 to 0.00045, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.9864e-04 - val_loss: 4.4897e-04
# Epoch 53/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.9855e-04
# Epoch 00053: val_loss improved from 0.00045 to 0.00043, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 1.9604e-04 - val_loss: 4.3150e-04
# Epoch 54/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.9632e-04
# Epoch 00054: val_loss did not improve from 0.00043
# 25/25 [==============================] - 0s 5ms/step - loss: 1.8902e-04 - val_loss: 4.3514e-04
# Epoch 55/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.8623e-04
# Epoch 00055: val_loss did not improve from 0.00043
# 25/25 [==============================] - 0s 5ms/step - loss: 1.8846e-04 - val_loss: 4.3228e-04
# Epoch 56/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.8549e-04
# Epoch 00056: val_loss did not improve from 0.00043
# 25/25 [==============================] - 0s 4ms/step - loss: 1.8256e-04 - val_loss: 4.3684e-04
# Epoch 57/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.7770e-04
# Epoch 00057: val_loss did not improve from 0.00043
# 25/25 [==============================] - 0s 4ms/step - loss: 1.8252e-04 - val_loss: 4.3237e-04
# Epoch 58/100
# 21/25 [========================>.....] - ETA: 0s - loss: 1.8643e-04
# Epoch 00058: val_loss improved from 0.00043 to 0.00042, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.8407e-04 - val_loss: 4.1983e-04
# Epoch 59/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.7776e-04
# Epoch 00059: val_loss improved from 0.00042 to 0.00042, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 1.8228e-04 - val_loss: 4.1841e-04
# Epoch 60/100
# 13/25 [==============>...............] - ETA: 0s - loss: 1.6638e-04
# Epoch 00060: val_loss improved from 0.00042 to 0.00041, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 9ms/step - loss: 1.7700e-04 - val_loss: 4.1372e-04
# Epoch 61/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.7637e-04
# Epoch 00061: val_loss did not improve from 0.00041
# 25/25 [==============================] - 0s 5ms/step - loss: 1.7380e-04 - val_loss: 4.2437e-04
# Epoch 62/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.8284e-04
# Epoch 00062: val_loss did not improve from 0.00041
# 25/25 [==============================] - 0s 4ms/step - loss: 1.8212e-04 - val_loss: 4.3895e-04
# Epoch 63/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.6078e-04
# Epoch 00063: val_loss did not improve from 0.00041
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7547e-04 - val_loss: 4.2111e-04
# Epoch 64/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.6071e-04
# Epoch 00064: val_loss did not improve from 0.00041
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7278e-04 - val_loss: 4.1418e-04
# Epoch 65/100
# 18/25 [====================>.........] - ETA: 0s - loss: 1.6710e-04
# Epoch 00065: val_loss did not improve from 0.00041
# 25/25 [==============================] - 0s 4ms/step - loss: 1.7463e-04 - val_loss: 4.2245e-04
# Epoch 66/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.5306e-04
# Epoch 00066: val_loss did not improve from 0.00041
# 25/25 [==============================] - 0s 5ms/step - loss: 1.6565e-04 - val_loss: 4.3170e-04
# Epoch 67/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.6759e-04
# Epoch 00067: val_loss improved from 0.00041 to 0.00041, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.6292e-04 - val_loss: 4.1125e-04
# Epoch 68/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.6420e-04
# Epoch 00068: val_loss improved from 0.00041 to 0.00040, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.5770e-04 - val_loss: 4.0452e-04
# Epoch 69/100
# 16/25 [==================>...........] - ETA: 0s - loss: 1.6038e-04
# Epoch 00069: val_loss improved from 0.00040 to 0.00040, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.5068e-04 - val_loss: 4.0378e-04
# Epoch 70/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.6137e-04
# Epoch 00070: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4947e-04 - val_loss: 4.0962e-04
# Epoch 71/100
# 16/25 [==================>...........] - ETA: 0s - loss: 1.2553e-04
# Epoch 00071: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4641e-04 - val_loss: 4.0468e-04
# Epoch 72/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.5222e-04
# Epoch 00072: val_loss improved from 0.00040 to 0.00040, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.5578e-04 - val_loss: 4.0238e-04
# Epoch 73/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.3988e-04
# Epoch 00073: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 5ms/step - loss: 1.5774e-04 - val_loss: 4.0701e-04
# Epoch 74/100
# 21/25 [========================>.....] - ETA: 0s - loss: 1.4916e-04
# Epoch 00074: val_loss improved from 0.00040 to 0.00040, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.4633e-04 - val_loss: 3.9723e-04
# Epoch 75/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.3450e-04
# Epoch 00075: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4211e-04 - val_loss: 3.9810e-04
# Epoch 76/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.5175e-04
# Epoch 00076: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4967e-04 - val_loss: 4.3333e-04
# Epoch 77/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.5963e-04
# Epoch 00077: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 4ms/step - loss: 1.8926e-04 - val_loss: 4.3789e-04
# Epoch 78/100
# 16/25 [==================>...........] - ETA: 0s - loss: 2.3442e-04
# Epoch 00078: val_loss did not improve from 0.00040
# 25/25 [==============================] - 0s 5ms/step - loss: 2.1452e-04 - val_loss: 4.0488e-04
# Epoch 79/100
# 21/25 [========================>.....] - ETA: 0s - loss: 1.5697e-04
# Epoch 00079: val_loss improved from 0.00040 to 0.00039, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 7ms/step - loss: 1.5628e-04 - val_loss: 3.9275e-04
# Epoch 80/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.3933e-04
# Epoch 00080: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3885e-04 - val_loss: 3.9396e-04
# Epoch 81/100
# 15/25 [=================>............] - ETA: 0s - loss: 1.5450e-04
# Epoch 00081: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 5ms/step - loss: 1.4064e-04 - val_loss: 4.0678e-04
# Epoch 82/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.2168e-04
# Epoch 00082: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4212e-04 - val_loss: 4.0497e-04
# Epoch 83/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.4633e-04
# Epoch 00083: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4689e-04 - val_loss: 3.9745e-04
# Epoch 84/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.3295e-04
# Epoch 00084: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3792e-04 - val_loss: 4.0338e-04
# Epoch 85/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.3942e-04
# Epoch 00085: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3314e-04 - val_loss: 3.9326e-04
# Epoch 86/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.2865e-04
# Epoch 00086: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3318e-04 - val_loss: 3.9337e-04
# Epoch 87/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.3581e-04
# Epoch 00087: val_loss did not improve from 0.00039
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3428e-04 - val_loss: 4.1028e-04
# Epoch 88/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.3167e-04
# Epoch 00088: val_loss improved from 0.00039 to 0.00038, saving model to /content/drive/My Drive/thesis-unsub/unsub/anomaly-transferlearning/Generic_Anomaly_Detection_Malware_TRANSFER-LEARNING/Transfer-Known-SimpleHomeCamera_Unknown-Provision-0.1.h5
# 25/25 [==============================] - 0s 8ms/step - loss: 1.2944e-04 - val_loss: 3.8337e-04
# Epoch 89/100
# 21/25 [========================>.....] - ETA: 0s - loss: 1.3166e-04
# Epoch 00089: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2739e-04 - val_loss: 3.8983e-04
# Epoch 90/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.2483e-04
# Epoch 00090: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2445e-04 - val_loss: 3.9128e-04
# Epoch 91/100
# 16/25 [==================>...........] - ETA: 0s - loss: 1.2852e-04
# Epoch 00091: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2881e-04 - val_loss: 3.9736e-04
# Epoch 92/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.3765e-04
# Epoch 00092: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2767e-04 - val_loss: 3.9443e-04
# Epoch 93/100
# 17/25 [===================>..........] - ETA: 0s - loss: 1.1939e-04
# Epoch 00093: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2710e-04 - val_loss: 3.8941e-04
# Epoch 94/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.2587e-04
# Epoch 00094: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2541e-04 - val_loss: 4.0226e-04
# Epoch 95/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.3218e-04
# Epoch 00095: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2329e-04 - val_loss: 3.8796e-04
# Epoch 96/100
# 20/25 [=======================>......] - ETA: 0s - loss: 1.3010e-04
# Epoch 00096: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.2663e-04 - val_loss: 3.9736e-04
# Epoch 97/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.2035e-04
# Epoch 00097: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2582e-04 - val_loss: 4.0257e-04
# Epoch 98/100
# 19/25 [=====================>........] - ETA: 0s - loss: 1.4609e-04
# Epoch 00098: val_loss did not improve from 0.00038
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3642e-04 - val_loss: 3.8500e-04
# time
# 16.800285577774048
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 85)]              0
#
#  dense_8 (Dense)             (None, 68)                5848
#
#  dense_9 (Dense)             (None, 51)                3519
#
#  dense_10 (Dense)            (None, 34)                1768
#
#  dense_11 (Dense)            (None, 17)                595
#
#  dense_12 (Dense)            (None, 34)                612
#
#  dense_13 (Dense)            (None, 51)                1785
#
#  dense_14 (Dense)            (None, 68)                3536
#
#  dense_15 (Dense)            (None, 85)                5865
#
# =================================================================
# Total params: 23,528
# Trainable params: 2,975
# Non-trainable params: 20,553
# _________________________________________________________________
# None

# %% [markdown]
# **Lets test the model on Known sample_test data first**
#
# We need a new threshold definition first,
#
# Following find the distribution of MSE in the sampled data. For reference we shall find distribution of the remaining data as well in the next cell

# %%
df_benign_unknown_device_test_predictions = transfer_model.predict(scaled_df_unknown_device_benign_sample_test[unknown_fs])


print("Shape of variable DF_BENIGN_TEST: " + str(scaled_df_unknown_device_benign_sample_test[unknown_fs].shape))
print("Shape of variable DF_BENIGN_TEST_PREDICTIONS: " + str(df_benign_unknown_device_test_predictions.shape))
unknown_difference = scaled_df_unknown_device_benign_sample_test[unknown_fs] - df_benign_unknown_device_test_predictions
print("Shape of the variable difference: " + str(unknown_difference.shape))

unknown_mse = np.mean(np.power(scaled_df_unknown_device_benign_sample_test[unknown_fs] - df_benign_unknown_device_test_predictions, 2), axis=1) # Mean-Squared-Error is calculated for each row,
                                                                                # all ten feature values are used to generate a single error
                                                                                # number.
#print(type(mse))
#print("Shape of Mean-Squared-Error: " + str(mse.shape))
unknown_mean = unknown_mse.mean() # We calculate the mean of the whole series, that is the mean mse for all the benign test cases.
unknown_std = unknown_mse.std() # And we calculate the standard deviation of the mse series, containing only the test cases.

unknown_mse = pd.Series(unknown_mse)
print("UNKNOWN_MSE_MAX TYPE:    " + str(type(unknown_mse)))
print("MIN of UNKNOWN_MSE_MAX: " + str(unknown_mse.min()))
print("MAX of UNKNOWN_MSE_MAX: " + str(unknown_mse.max()))
print("MEAN of UNKNOWN_MSE_MAX: " + str(unknown_mean))
print("STD of UNKNOWN_MSE_MAX:  " + str(unknown_std))

unknown_mse_min = unknown_mse.min()
unknown_mse_max = unknown_mse.max()
print("\nMax Threshold = UNKNOWN_MSE_MAX: " + str(unknown_mse_max))

unknown_max_std_multiplier = int((unknown_mse_max - unknown_mean) / unknown_std)
print("\nMAX_STD_Multiplier = " + str(unknown_max_std_multiplier))



# Identifying a quantile distribution on the basis that the records of large MSE maybe an anomaly.
# We postulate that records with MSE residing above the 95th percentile may be erroneous
# Attempting to find the STD Multiplier corresponding to the 95th percentile
#Anomaly Threshold percentile                                                
unknown_test_percentile = 0.995

unknown_quantile_mse = unknown_mse[unknown_mse <= unknown_mse.quantile(q=unknown_test_percentile)]

print("MIN of QUANTILE_MSE: " + str(unknown_quantile_mse.min()))
print("MAX of QUANTILE_MSE: " + str(unknown_quantile_mse.max()))
print("MEAN of QUANTILE_MSE: " + str(unknown_quantile_mse.mean()))
print("STD of QUNATILE_MSE:  " + str(unknown_quantile_mse.std()))

print("Size of Series below " + str(unknown_test_percentile) + " quantile: " + str(unknown_quantile_mse.size))

print("\nSuggested Minimum Threshold = QUANTILE_MSE_MAX: " + str(unknown_quantile_mse.max()))

unknown_min_std_multiplier = int((unknown_quantile_mse.max() - unknown_quantile_mse.mean()) / unknown_quantile_mse.std())
print("\nMIN_STD_Multiplier = " + str(unknown_min_std_multiplier))


unknown_quantile_mse_plot = unknown_quantile_mse.plot.hist(bins=20)
unknown_quantile_mse_plot.set_xlim((unknown_quantile_mse.min(), unknown_quantile_mse.max()))
unknown_quantile_mse_plot.set_ylim((0, unknown_quantile_mse[unknown_quantile_mse <= unknown_quantile_mse.max()].count()))
# Out:
# Shape of variable DF_BENIGN_TEST: (263, 85)
# Shape of variable DF_BENIGN_TEST_PREDICTIONS: (263, 85)
# Shape of the variable difference: (263, 85)
# UNKNOWN_MSE_MAX TYPE:    <class 'pandas.core.series.Series'>
# MIN of UNKNOWN_MSE_MAX: 8.661766941792094e-06
# MAX of UNKNOWN_MSE_MAX: 0.003015736809528814
# MEAN of UNKNOWN_MSE_MAX: 0.0001033825062562661
# STD of UNKNOWN_MSE_MAX:  0.0002431262640789053
#
# Max Threshold = UNKNOWN_MSE_MAX: 0.003015736809528814
#
# MAX_STD_Multiplier = 11
# MIN of QUANTILE_MSE: 8.661766941792094e-06
# MAX of QUANTILE_MSE: 0.0011565294603807495
# MEAN of QUANTILE_MSE: 8.728100904515649e-05
# STD of QUNATILE_MSE:  0.0001424104785636151
# Size of Series below 0.995 quantile: 261
#
# Suggested Minimum Threshold = QUANTILE_MSE_MAX: 0.0011565294603807495
#
# MIN_STD_Multiplier = 7
# (0.0, 261.0)

# %%
##  Find Mean and MSE in the remaining part of the dataframe;


df_unknown_device_benign_remaining_predictions = transfer_model.predict(scaled_df_unknown_device_benign_remaining[unknown_fs])


print("Shape of variable DF_BENIGN_TEST: " + str(scaled_df_unknown_device_benign_remaining[unknown_fs].shape))
print("Shape of variable DF_BENIGN_TEST_PREDICTIONS: " + str(df_unknown_device_benign_remaining_predictions.shape))
remaining_unknown_difference = scaled_df_unknown_device_benign_remaining[unknown_fs] - df_unknown_device_benign_remaining_predictions
print("Shape of the variable difference: " + str(remaining_unknown_difference.shape))

remaining_unknown_mse = np.mean(np.power(scaled_df_unknown_device_benign_remaining[unknown_fs] - df_unknown_device_benign_remaining_predictions, 2), axis=1) # Mean-Squared-Error is calculated for each row,
                                                                                # all ten feature values are used to generate a single error
                                                                                # number.
#print(type(mse))
#print("Shape of Mean-Squared-Error: " + str(mse.shape))
remaining_unknown_mean = remaining_unknown_mse.mean() # We calculate the mean of the whole series, that is the mean mse for all the benign test cases.
remaining_unknown_std = remaining_unknown_mse.std() # And we calculate the standard deviation of the mse series, containing only the test cases.

remaining_unknown_mse = pd.Series(remaining_unknown_mse)
print("UNKNOWN_MSE_MAX TYPE:    " + str(type(remaining_unknown_mse)))
print("MIN of UNKNOWN_MSE_MAX: " + str(remaining_unknown_mse.min()))
print("MAX of UNKNOWN_MSE_MAX: " + str(remaining_unknown_mse.max()))
print("MEAN of UNKNOWN_MSE_MAX: " + str(remaining_unknown_mean))
print("STD of UNKNOWN_MSE_MAX:  " + str(remaining_unknown_std))

remaining_unknown_mse_min = remaining_unknown_mse.min()
remaining_unknown_mse_max = remaining_unknown_mse.max()
print("\nMax Threshold = UNKNOWN_MSE_MAX: " + str(remaining_unknown_mse_max))

remaining_unknown_max_std_multiplier = int((remaining_unknown_mse_max - remaining_unknown_mean) / remaining_unknown_std)
print("\nMAX_STD_Multiplier = " + str(remaining_unknown_max_std_multiplier))



# Identifying a quantile distribution on the basis that the records of large MSE maybe an anomaly.
# We postulate that records with MSE residing above the 95th percentile may be erroneous
# Attempting to find the STD Multiplier corresponding to the 95th percentile
#Anomaly Threshold percentile                                                
remaining_unknown_test_percentile = 0.995

remaining_unknown_quantile_mse = remaining_unknown_mse[remaining_unknown_mse <= remaining_unknown_mse.quantile(q=remaining_unknown_test_percentile)]

print("MIN of QUANTILE_MSE: " + str(remaining_unknown_quantile_mse.min()))
print("MAX of QUANTILE_MSE: " + str(remaining_unknown_quantile_mse.max()))
print("MEAN of QUANTILE_MSE: " + str(remaining_unknown_quantile_mse.mean()))
print("STD of QUNATILE_MSE:  " + str(remaining_unknown_quantile_mse.std()))

print("Size of Series below " + str(remaining_unknown_test_percentile) + " quantile: " + str(remaining_unknown_quantile_mse.size))

print("\nSuggested Minimum Threshold = QUANTILE_MSE_MAX: " + str(remaining_unknown_quantile_mse.max()))

remaining_unknown_min_std_multiplier = int((remaining_unknown_quantile_mse.max() - remaining_unknown_quantile_mse.mean()) / remaining_unknown_quantile_mse.std())
print("\nMIN_STD_Multiplier = " + str(remaining_unknown_min_std_multiplier))


remaining_unknown_quantile_mse_plot = remaining_unknown_quantile_mse.plot.hist(bins=20)
remaining_unknown_quantile_mse_plot.set_xlim((remaining_unknown_quantile_mse.min(), remaining_unknown_quantile_mse.max()))
remaining_unknown_quantile_mse_plot.set_ylim((0, remaining_unknown_quantile_mse[remaining_unknown_quantile_mse <= remaining_unknown_quantile_mse.max()].count()))
# Out:
# Shape of variable DF_BENIGN_TEST: (11802, 85)
# Shape of variable DF_BENIGN_TEST_PREDICTIONS: (11802, 85)
# Shape of the variable difference: (11802, 85)
# UNKNOWN_MSE_MAX TYPE:    <class 'pandas.core.series.Series'>
# MIN of UNKNOWN_MSE_MAX: 7.516916589024062e-06
# MAX of UNKNOWN_MSE_MAX: 0.06777425071543836
# MEAN of UNKNOWN_MSE_MAX: 0.0002897233483359652
# STD of UNKNOWN_MSE_MAX:  0.002987622852281963
#
# Max Threshold = UNKNOWN_MSE_MAX: 0.06777425071543836
#
# MAX_STD_Multiplier = 22
# MIN of QUANTILE_MSE: 7.516916589024062e-06
# MAX of QUANTILE_MSE: 0.005377276407245006
# MEAN of QUANTILE_MSE: 0.00012127357251264266
# STD of QUNATILE_MSE:  0.0003096000459001628
# Size of Series below 0.995 quantile: 11742
#
# Suggested Minimum Threshold = QUANTILE_MSE_MAX: 0.005377276407245006
#
# MIN_STD_Multiplier = 16
# (0.0, 11742.0)

# %% [markdown]
# ### We need to understand how the attack data is distributed

# %%
##  Find Mean and MSE in the remaining part of the dataframe;


df_unknown_device_attack_predictions = transfer_model.predict(scaled_df_unknown_device_attack[unknown_fs])


print("Shape of variable DF_ATTACK: " + str(scaled_df_unknown_device_attack[unknown_fs].shape))
print("Shape of variable DF_ATTACK_PREDICTIONS: " + str(df_unknown_device_attack_predictions.shape))
attack_unknown_difference = scaled_df_unknown_device_attack[unknown_fs] - df_unknown_device_attack_predictions
print("Shape of the variable difference: " + str(attack_unknown_difference.shape))

attack_unknown_mse = np.mean(np.power(scaled_df_unknown_device_attack[unknown_fs] - df_unknown_device_attack_predictions, 2), axis=1) # Mean-Squared-Error is calculated for each row,
                                                                                # all ten feature values are used to generate a single error
                                                                                # number.
#print(type(mse))
#print("Shape of Mean-Squared-Error: " + str(mse.shape))
attack_unknown_mean = attack_unknown_mse.mean() # We calculate the mean of the whole series, that is the mean mse for all the benign test cases.
attack_unknown_std = attack_unknown_mse.std() # And we calculate the standard deviation of the mse series, containing only the test cases.

attack_unknown_mse = pd.Series(attack_unknown_mse)
print("UNKNOWN_MSE_MAX TYPE:    " + str(type(attack_unknown_mse)))
print("MIN of UNKNOWN_MSE_MAX: " + str(attack_unknown_mse.min()))
print("MAX of UNKNOWN_MSE_MAX: " + str(attack_unknown_mse.max()))
print("MEAN of UNKNOWN_MSE_MAX: " + str(attack_unknown_mean))
print("STD of UNKNOWN_MSE_MAX:  " + str(attack_unknown_std))

attack_unknown_mse_min = attack_unknown_mse.min()
attack_unknown_mse_max = attack_unknown_mse.max()
print("\nMax Threshold = UNKNOWN_MSE_MAX: " + str(attack_unknown_mse_max))

attack_unknown_max_std_multiplier = int((attack_unknown_mse_max - attack_unknown_mean) / attack_unknown_std)
print("\nMAX_STD_Multiplier = " + str(attack_unknown_max_std_multiplier))



# Identifying a quantile distribution on the basis that the records of large MSE maybe an anomaly.
# We postulate that records with MSE residing above the 95th percentile may be erroneous
# Attempting to find the STD Multiplier corresponding to the 95th percentile
#Anomaly Threshold percentile     

## Number of records with values less than UNKNOWN_MSE_MAX
print("Size of Series below MAX of UNKNOWN_MSE: " + str(attack_unknown_mse[attack_unknown_mse <= unknown_mse_max].size))
print("Size of Series below " + str(unknown_test_percentile) + " quantile of QUANTILE_UNKNOWN_MSE: " + str(attack_unknown_mse[attack_unknown_mse <= unknown_quantile_mse.max()].size))

## Number of records with values less than REMAINING_UNKNOWN_MSE_MAX
print("Size of Series below MAX of REMAINING_UNKNOWN_MSE: " + str(attack_unknown_mse[attack_unknown_mse <= remaining_unknown_mse_max].size))
print("Size of Series below " + str(remaining_unknown_test_percentile) + " quantile of REMAINING UNKNOWN_MSE: " + str(attack_unknown_mse[attack_unknown_mse <= remaining_unknown_quantile_mse.max()].size))
# Out:
# Shape of variable DF_ATTACK: (310630, 85)
# Shape of variable DF_ATTACK_PREDICTIONS: (310630, 85)
# Shape of the variable difference: (310630, 85)
# UNKNOWN_MSE_MAX TYPE:    <class 'pandas.core.series.Series'>
# MIN of UNKNOWN_MSE_MAX: 0.0007719817720738888
# MAX of UNKNOWN_MSE_MAX: 649.7691534236575
# MEAN of UNKNOWN_MSE_MAX: 76.56750917356702
# STD of UNKNOWN_MSE_MAX:  149.76542555580235
#
# Max Threshold = UNKNOWN_MSE_MAX: 649.7691534236575
#
# MAX_STD_Multiplier = 3
# Size of Series below MAX of UNKNOWN_MSE: 43
# Size of Series below 0.995 quantile of QUANTILE_UNKNOWN_MSE: 7
# Size of Series below MAX of REMAINING_UNKNOWN_MSE: 199833
# Size of Series below 0.995 quantile of REMAINING UNKNOWN_MSE: 77

# %%
# Testing the accuracy of the anomaly model on the known_devices attack data

# While we have used the benign_test dataset to define a threshold, its unknown to the model itself since no parameters learnt have used values from this dataset.
# We shall thus use a random mix of benign_test dataset and the attack_dataset for our testing.

unknown_df_benign = scaled_df_unknown_device_benign_sample_test[unknown_fs] # "fs" is a list containing all the top features (based on Fisher score) of the old device. #Creating Labeled datasets 
unknown_df_benign['malicious'] = 0

#print("Shape of Benign Dataframe")
#unknown_df_benign.info()


unknown_df_malicious = scaled_df_unknown_device_attack.sample(n=scaled_df_unknown_device_benign_sample_test.shape[0])[unknown_fs] # Keeping equal parts of benign / malicious data
unknown_df_malicious['malicious'] = 1

#print("Shape of Malicious DataFrame")
#unknown_df_malicious.info()

anomaly_detect_03_df = unknown_df_benign.append(unknown_df_malicious)
anomaly_detect_03_X_test = anomaly_detect_03_df.drop(columns=['malicious']).values
anomaly_detect_03_Y_test = anomaly_detect_03_df['malicious'] # This shall form the ground truth series of values.
#print(Y_test)

#for threshold in [mse_max, quantile_mse.max()]:
for threshold in [unknown_mse_max, unknown_quantile_mse.max()]:
  print("Threshold: " + str(threshold))
  m = AnomalyModel(transfer_model , threshold, scaler)
  anomaly_detect_03_Y_pred = m.predict(anomaly_detect_03_X_test)
  print('Test-----------------')
  #print(f'suggensted threshodl n {best_n}')
  print('Accuracy')
  anomaly_detect_03_acc = accuracy_score(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred)
  print(anomaly_detect_03_acc)
  print('Precision')
  anomaly_detect_03_prec=precision_score(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred)
  print(anomaly_detect_03_prec)
  print('CM')
  anomaly_detect_03_cm = confusion_matrix(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred, labels=[0,1])
  print(anomaly_detect_03_cm)  
  print(type(anomaly_detect_03_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_03_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
# Out:
# Threshold: 0.003015736809528814
# Test-----------------
# Accuracy
# 1.0
# Precision
# 1.0
# CM
# [[263   0]
#  [  0 263]]
# <class 'numpy.ndarray'>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Threshold: 0.0011565294603807495
# Test-----------------
# Accuracy
# 0.9961977186311787
# Precision
# 0.9924528301886792
# CM
# [[261   2]
#  [  0 263]]
# <class 'numpy.ndarray'>

# %%
print('Starting Accuracy')
starting_accuracy = anomaly_detect_03_acc
base_acc = anomaly_detect_03_acc
print(base_acc)
print('Starting Precision')
base_precision = anomaly_detect_03_prec
print(base_precision)

new_percentile = 0.995
#new_percentile = new_percentile - 0.005
some_increase_found = False

candidate_threshold = unknown_mse[unknown_mse <= unknown_mse.quantile(q=new_percentile)].max()

while True:
  if new_percentile <= 0.9:
    print("reached quite  low percentile of 0.90 ... Aborting")
    anomaly_detect_03_chosen_threshold = unknown_mse[unknown_mse <= unknown_mse.quantile(q=1)].max()
    print("selected threshold is: " + str(anomaly_detect_03_chosen_threshold))    
    break
  threshold = unknown_mse[unknown_mse <= unknown_mse.quantile(q=new_percentile)].max()
  print("Current Threshold: " + str(threshold))
  m = AnomalyModel(model, threshold, scaler)
  anomaly_detect_03_Y_pred = m.predict(anomaly_detect_03_X_test)
  new_acc = accuracy_score(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred)
  new_precision = precision_score(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred)
  print("new_acc: " + str(new_acc) + " ... new_precision: " + str(new_precision))
  if new_acc > base_acc:
    print("new_acc > base_acc")
    candidate_threshold = threshold
    # saving old base for comparison later
    #old_acc = base_acc
    #old_precision = base_precision
    # defining new base 
    base_acc = new_acc
    base_precision = new_precision
    # decreasing percentile for next test
    new_percentile = new_percentile - 0.005
    print("Next Percentile to test " + str(new_percentile) + "\n-------------------\n")
    some_increase_found = True
  elif new_acc < base_acc:
    print("NEW-ACC < BASE-ACC")
    if some_increase_found:
      val = input("Accuracy has started to decrease, stop now? (y/n) ")
      if val == 'y':
        print("Phew... \n\n")
        print("selected percentile for threshold is: " + str(new_percentile + 0.005))
        print("selected threshold is: " + str(unknown_mse[unknown_mse <= unknown_mse.quantile(q=(new_percentile + 0.005))].max()))
        anomaly_detect_03_chosen_threshold = unknown_mse[unknown_mse <= unknown_mse.quantile(q=(new_percentile + 0.005))].max()
        break
    new_percentile = new_percentile - 0.005
    print("Next Percentile to test " + str(new_percentile))
    continue
  else:
    new_percentile = new_percentile - 0.005
    print("Next Percentile to test " + str(new_percentile))

if new_acc > starting_accuracy:
  print('CM')
  anomaly_detect_03_cm = confusion_matrix(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred, labels=[0,1])
  print(anomaly_detect_03_cm)  
  print(type(anomaly_detect_03_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_03_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
else:
  anomaly_detect_03_chosen_threshold = unknown_mse[unknown_mse <= unknown_mse.quantile(q=1)].max()
  print("Chosen Threshold: " + str(anomaly_detect_03_chosen_threshold))
  print("This is MSE MAX")
  print('CM')
  anomaly_detect_03_cm = confusion_matrix(anomaly_detect_03_Y_test, anomaly_detect_03_Y_pred, labels=[0,1])
  print(anomaly_detect_03_cm)  
  print(type(anomaly_detect_03_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_03_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
# Out:
# Starting Accuracy
# 0.9961977186311787
# Starting Precision
# 0.9924528301886792
# Current Threshold: 0.0011565294603807495
# new_acc: 0.9961977186311787 ... new_precision: 0.9924528301886792
# Next Percentile to test 0.99
# Current Threshold: 0.0010309457615139263
# new_acc: 0.9942965779467681 ... new_precision: 0.9887218045112782
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.985
# Current Threshold: 0.0008834891383430963
# new_acc: 0.9923954372623575 ... new_precision: 0.9850187265917603
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.98
# Current Threshold: 0.0006761368437803755
# new_acc: 0.9866920152091255 ... new_precision: 0.9740740740740741
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.975
# Current Threshold: 0.0005848830394066863
# new_acc: 0.9847908745247148 ... new_precision: 0.9704797047970479
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.97
# Current Threshold: 0.00048371507445245696
# new_acc: 0.9847908745247148 ... new_precision: 0.9704797047970479
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.965
# Current Threshold: 0.00037611058151824445
# new_acc: 0.9809885931558935 ... new_precision: 0.9633699633699634
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.96
# Current Threshold: 0.00033206189145751835
# new_acc: 0.9771863117870723 ... new_precision: 0.9563636363636364
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.955
# Current Threshold: 0.00031905299617251986
# new_acc: 0.9752851711026616 ... new_precision: 0.9528985507246377
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.95
# Current Threshold: 0.0002941279270265401
# new_acc: 0.973384030418251 ... new_precision: 0.9494584837545126
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.945
# Current Threshold: 0.0002899768140440442
# new_acc: 0.9695817490494296 ... new_precision: 0.942652329749104
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.94
# Current Threshold: 0.00028888376988538264
# new_acc: 0.9695817490494296 ... new_precision: 0.942652329749104
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9349999999999999
# Current Threshold: 0.0002855481547389691
# new_acc: 0.9657794676806084 ... new_precision: 0.9359430604982206
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9299999999999999
# Current Threshold: 0.000262853322301498
# new_acc: 0.9619771863117871 ... new_precision: 0.9293286219081273
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9249999999999999
# Current Threshold: 0.00025132479099135513
# new_acc: 0.9600760456273765 ... new_precision: 0.926056338028169
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9199999999999999
# Current Threshold: 0.00024682323733878243
# new_acc: 0.9600760456273765 ... new_precision: 0.926056338028169
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9149999999999999
# Current Threshold: 0.00020560122523860042
# new_acc: 0.9543726235741445 ... new_precision: 0.9163763066202091
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9099999999999999
# Current Threshold: 0.0001941469048283008
# new_acc: 0.9543726235741445 ... new_precision: 0.9163763066202091
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.9049999999999999
# Current Threshold: 0.00018175969019093411
# new_acc: 0.9505703422053232 ... new_precision: 0.9100346020761245
# NEW-ACC < BASE-ACC
# Next Percentile to test 0.8999999999999999
# reached quite  low percentile of 0.90 ... Aborting
# selected threshold is: 0.003015736809528814
# Chosen Threshold: 0.003015736809528814
# This is MSE MAX
# CM
# [[237  26]
#  [  0 263]]
# <class 'numpy.ndarray'>

# %% [markdown]
# **Finally, lets test on unknown data**

# %%
# Testing the accuracy of the anomaly model on the known_devices attack data

# While we have used the benign_test dataset to define a threshold, its unknown to the model itself since no parameters learnt have used values from this dataset.
# We shall thus use a random mix of benign_test dataset and the attack_dataset for our testing.

anomaly_detect_04_unknown_df_benign = scaled_df_unknown_device_benign_remaining[unknown_fs] # "fs" is a list containing all the top features (based on Fisher score) of the old device. #Creating Labeled datasets 
anomaly_detect_04_unknown_df_benign['malicious'] = 0

#print("Shape of Benign Dataframe")
#unknown_df_benign.info()


anomaly_detect_04_unknown_df_malicious = scaled_df_unknown_device_attack.sample(n=scaled_df_unknown_device_benign_remaining.shape[0])[unknown_fs] # Keeping equal parts of benign / malicious data
anomaly_detect_04_unknown_df_malicious['malicious'] = 1

#print("Shape of Malicious DataFrame")
#unknown_df_malicious.info()

anomaly_detect_04_df = anomaly_detect_04_unknown_df_benign.append(anomaly_detect_04_unknown_df_malicious)
anomaly_detect_04_X_test = anomaly_detect_04_df.drop(columns=['malicious']).values
anomaly_detect_04_Y_test = anomaly_detect_04_df['malicious'] # This shall form the ground truth series of values.
#print(Y_test)

#for threshold in [mse_max, quantile_mse.max()]:
for threshold in [anomaly_detect_03_chosen_threshold, unknown_quantile_mse.max(),unknown_mse[unknown_mse <= unknown_mse.quantile(q=0.97)].max()]:
  print("Threshold: " + str(threshold))
  m = AnomalyModel(transfer_model , threshold, scaler)
  anomaly_detect_04_Y_pred = m.predict(anomaly_detect_04_X_test)
  print('Test-----------------')
  #print(f'suggensted threshodl n {best_n}')
  print('Accuracy')
  anomaly_detect_04_acc = accuracy_score(anomaly_detect_04_Y_test, anomaly_detect_04_Y_pred)
  print(anomaly_detect_04_acc)
  print('Precision')
  print(precision_score(anomaly_detect_04_Y_test, anomaly_detect_04_Y_pred))
  print('CM')
  anomaly_detect_04_cm = confusion_matrix(anomaly_detect_04_Y_test, anomaly_detect_04_Y_pred, labels=[0,1])
  print(anomaly_detect_04_cm)  
  print(type(anomaly_detect_04_cm)) 
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(anomaly_detect_04_cm)
  plt.title('Confusion matrix')
  fig.colorbar(cax)
  labels=['0','1']
  ax.set_xticklabels([''] + labels)
  ax.set_yticklabels([''] + labels)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Threshold: 0.003015736809528814
# Test-----------------
# Accuracy
# 0.9958481613285883
# Precision
# 0.9918473693057657
# CM
# [[11705    97]
#  [    1 11801]]
# <class 'numpy.ndarray'>
# Threshold: 0.0011565294603807495
# Test-----------------
# Accuracy
# 0.9909337400440603
# Precision
# 0.982190412782956
# CM
# [[11588   214]
#  [    0 11802]]
# <class 'numpy.ndarray'>
# Threshold: 0.00048371507445245696
# Test-----------------
# Accuracy
# 0.9775038129130655
# Precision
# 0.9569447822914133
# CM
# [[11271   531]
#  [    0 11802]]
# <class 'numpy.ndarray'>
